# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_dir = '/content/drive/MyDrive/데이콘/데이콘 항공편 지연/데이콘_항공편_지연'

# %%
import numpy as np
import random
import os
import gc

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(42) # Seed 고정

# %%
def csv_to_parquet(csv_path, save_name):
    df = pd.read_csv(csv_path)
    df.to_parquet(f'./{save_name}.parquet')
    del df
    gc.collect()
    print(save_name, 'Done.')

# %%
csv_to_parquet(file_dir + '/train.csv', 'train')
csv_to_parquet(file_dir + '/test.csv', 'test')
# Out:
# train Done.
# test Done.

# %%
train = pd.read_parquet('/content/train.parquet')
test = pd.read_parquet('/content/test.parquet')
sample_submission = pd.read_csv(file_dir+'/sample_submission.csv', index_col = 0)

# %% [markdown]
# # 데이터 전처리 파이프라인

# %%
import itertools
from tqdm import tqdm
from datetime import datetime, timedelta
pd.set_option('mode.chained_assignment',  None)
class Processing:
    def __init__(self, x, test): # 이후 테스트 데이터도 넣는 버전 만들어야함
        self.x = x
        self.test = test
    
    def fill_airline_and_id_2(self, data):
        master_dil = '/content/drive/MyDrive/데이콘/데이콘 항공편 지연/데이콘_항공편_지연/ReleasableAircraft.2019/MASTER.txt'
        df = []
        with open(master_dil, 'r', encoding = "utf-8-sig") as file:
           df.append(file.readlines())
           
        df = list(itertools.chain(*df))  
        df = [line.split(',') for line in df]
        col = df[0]
        df = pd.DataFrame(df, columns = col)
        Airline2 = df[['N-NUMBER', 'NAME']].rename(columns={'N-NUMBER' : 'Tail_Number', 'NAME' : 'NAME2'})
        df['Tail_Number'] = ['N' + i for i in df['N-NUMBER']]
        Airline = df[['Tail_Number', 'NAME']]

        data = pd.merge(data, Airline, left_on = 'Tail_Number', right_on = 'Tail_Number', how = 'left')
        ar = pd.merge(data, Airline2, left_on = 'Tail_Number', right_on = 'Tail_Number', how = 'left')
        
        ar.loc[ar['Tail_Number'] == 'N297AK', 'NAME'] = 'ALASKA AIRLINES INC'
        ar.loc[ar['Tail_Number'] == '276NV', 'NAME'] = 'ALLEGIANT AIR LLC'
        
        ar = ar.fillna('nan')
        
        # DB-NAME을 Train Airline 기준으로 바꿈
        for base in ar.loc[~ar['Airline'].isin(['nan']), 'Airline'].unique():
            name1 = ar.loc[(ar['Airline'] == base) & ~(ar['NAME'].isin(['nan'])) & ~(ar['NAME'].isin(ar['Airline'].unique())), 'NAME'].unique()
            name2 = ar.loc[(ar['Airline'] == base) & ~(ar['NAME2'].isin(['nan'])) & ~(ar['NAME2'].isin(ar['Airline'].unique())), 'NAME2'].unique()
            ar['NAME'].replace(name1, base, inplace=True)
            ar['NAME2'].replace(name2, base, inplace=True)
        
        def apy(x):
            if x['NAME'] != 'nan':
                x['Airline'] = x['NAME']
            elif (x['NAME'] == 'nan') & (x['NAME2'] != 'nan'):
                x['Airline'] = x['NAME2']
            return x
        
        ar.loc[ar['Airline'] == 'nan'] = ar.loc[ar['Airline'] == 'nan'].apply(apy, axis=1)
        
        for n in ar[ar['Airline'] == 'nan']['Tail_Number'].unique():
            if ar.loc[ar['Tail_Number'] == n, ['Airline', 'Carrier_ID(DOT)']].shape[0] != ar.loc[(ar['Tail_Number'] == n) & ~(ar['Airline'].isin(['nan'])), ['Airline', 'Carrier_ID(DOT)']].shape[0]:
                ar.loc[ar['Tail_Number'] == n, 'Airline'] = ar.loc[(ar['Tail_Number'] == n) & ~(ar['Airline'].isin(['nan'])), 'Airline'].unique()[0]
                ar.loc[ar['Tail_Number'] == n, 'Carrier_ID(DOT)'] = ar.loc[(ar['Tail_Number'] == n) & ~(ar['Airline'].isin(['nan'])), 'Carrier_ID(DOT)'].unique()[0]
        
        ar['Airline'] = ar['Airline'].str.rstrip()
        ar['Airline'] = ar['Airline'].str.split('.').str[0]
        
        # ID 다시채움
        for airline in ar['Airline'].unique():
            id = ar.loc[(ar['Airline'] == airline) & ~(ar['Carrier_ID(DOT)'].isin(['nan'])), 'Carrier_ID(DOT)'].unique()
            ar.loc[ar['Airline'] == airline, 'Carrier_ID(DOT)'] = id[0]
        
        return ar
                
    def to_time(self, data, where = None):
        if where == None:
            print('where 넣어야함')
            return None
        
        def to_time(time_list):
            if where == 'first':
                Time = pd.Series(time_list).astype(str).str.zfill(4)
                Time = Time.replace('2400','0000')
                return [datetime.strptime(i, '%H%M').strftime("%H:%M") if i != '0nan' else np.NaN for i in Time]
            
            elif where == 'twice':
                Time = pd.Series(time_list)
                Time = Time.replace('2400','0000')
                Time = Time.replace('9999','1557')
                return [datetime.strptime(i, '%H%M').strftime("%H:%M") for i in Time]  
        
        def time_gb(x):
            if x >= 600 and x <= 659:
                return '0600-0659'
            elif x>=1400 and x<=1459:
                return '1400-1459'
            elif x>=1200 and x<=1259:
                return '1200-1259'
            elif x>=1500 and x<=1559:
                return '1500-1559'
            elif x>=1900 and x<=1959:
                return '1900-1959'
            elif x>=900 and x<=959:
                return '0900-0959'
            elif x>=1000 and x<=1059:
                return  '1000-1059'
            elif x>=2000 and x<=2059:
                return '2000-2059'
            elif x>=1300 and x<=1359:
                return '1300-1359'
            elif x>=1100 and x<=1159:
                return '1100-1159'
            elif x>=800 and x<=859:
                return '0800-0859'
            elif x>=2200 and x<=2259:
                return '2200-2259'
            elif x>=1600 and x<=1659:
                return '1600-1659'
            elif x>=1700 and x<=1759:
                return '1700-1759'
            elif x>=2100 and x<=2159:
                return '2100-2159'
            elif x>=700 and x<=759:
                return '0700-0759'
            elif x>=1800 and x<=1859:
                return '1800-1859'
            elif x>=1 and x<=559:
                return '0001-0559'
            elif x>=2300 and x<=2400:
                return '2300-2400'
            
        def distance_gb(x):
            if x < 700 :
                return 'short_route'
            elif x>=700 and x<3000:
                return 'mid_route'
            elif x>=3000:
                return 'long_route'    
        
        if where == 'first':
            time_list = [i if str(i) == 'nan' else str(int(i))  for i in data['Estimated_Departure_Time'] ]
            time_list1 = [i if str(i) == 'nan' else str(int(i))  for i in data['Estimated_Arrival_Time'] ]
            
        elif where == 'twice':
            time_list = [i for i in data['Estimated_Departure_Time']]
            time_list1 = [i for i in data['Estimated_Arrival_Time']]
        data['Estimated_Departure_Time_HH:MM'] = to_time(time_list)
        data['Estimated_Arrival_Time_HH:MM'] = to_time(time_list1)
    
        
        # 예상 비행시간 만들기 (분으로 만들기)
        data_est_time = []
        for i,j in zip(data['Estimated_Arrival_Time_HH:MM'], data['Estimated_Departure_Time_HH:MM']):
            if str(i) != 'nan' and str(j) != 'nan':
                if (datetime.strptime(str(i), "%H:%M") - datetime.strptime(str(j), "%H:%M")).total_seconds()/60 >= 0:
                    data_est_time.append((datetime.strptime(str(i), "%H:%M") - datetime.strptime(str(j), "%H:%M")).total_seconds()/60)
                else:
                    time = datetime.strptime(str(i), "%H:%M") - datetime.strptime(str(j), "%H:%M") + datetime.strptime('23:59', "%H:%M") + timedelta(minutes=1)
                    data_est_time.append(timedelta(hours=time.hour,minutes=time.minute ).total_seconds()/60)
            else:
                data_est_time.append(np.NaN)
        
        if where == 'first':
            data['Estimated_Time'] = data_est_time
            data['Dep_time_gb'] = data['Estimated_Departure_Time'].dropna().apply(time_gb)
            data['Arr_time_gb'] = data['Estimated_Arrival_Time'].dropna().apply(time_gb)
            data['route_gb'] = data['Distance'].apply(distance_gb)
            
        elif where == 'twice':
            data['Estimated_Time'] = data_est_time
            data['Dep_time_gb'] = data['Estimated_Departure_Time'].astype(int).apply(time_gb)
            data['Arr_time_gb'] = data['Estimated_Arrival_Time'].astype(int).apply(time_gb)
            data['route_gb'] = data['Distance'].apply(distance_gb)
        
        return data
        
    
    def fill_airline_and_id(self, data):
        
        for airline in data['Airline'].dropna().unique():
            id = data.loc[data['Airline'] == airline, 'Carrier_ID(DOT)'].dropna().unique()
            data.loc[data['Airline'] == airline, 'Carrier_ID(DOT)'] = id[0]
                

        for id in data['Carrier_ID(DOT)'].dropna().unique():
            airline = data.loc[data['Carrier_ID(DOT)'] == id, 'Airline'].dropna().unique()
            data.loc[data['Carrier_ID(DOT)'] == id, 'Airline'] = airline[0]
            
        return data
    
    def fill_state(self, data):
        for id in data['Origin_Airport_ID'].dropna().unique():
            # 테스트셋에 알수없는 Origin State -> dummy로 채움
            try:
                data.loc[data['Origin_Airport_ID'] == id, 'Origin_State'] = data.loc[data['Origin_Airport_ID'] == id, 'Origin_State'].dropna().unique()[0]
            except:
                data.loc[data['Origin_Airport_ID'] == id, 'Origin_State'] = 'dummy'
        
        for id in data['Destination_Airport_ID'].dropna().unique():
            try:
                data.loc[data['Destination_Airport_ID'] == id, 'Destination_State'] = data.loc[data['Destination_Airport_ID'] == id, 'Destination_State'].dropna().unique()[0]
            except: # 기록이 하나밖에 없음. Youngstown (YNG 공항)
                data.loc[data['Destination_Airport_ID'] == id, 'Destination_State'] = 'Youngstown'
        return data
        
    def fill_timedata(self, data, where=None):
        if where == 'at':
            time1 = 'Estimated_Departure_Time'
            time2 = 'Estimated_Arrival_Time'
            
        elif where == 'dt':
            time1 = 'Estimated_Arrival_Time'
            time2 = 'Estimated_Departure_Time'
            
        elif where == 'both':
            b_data = data[(data['Estimated_Arrival_Time'] != 'nan') & (data['Estimated_Departure_Time'] != 'nan')]
            b_data = b_data.groupby(['Origin_Airport', 'Destination_Airport', 'Airline'])['Estimated_Arrival_Time', 'Estimated_Departure_Time'].value_counts()
            b_data = b_data.reset_index()
            b_data = b_data.rename(columns={0:'count'})
            b_data = b_data.sort_values(['Origin_Airport', 'Destination_Airport', 'Airline', 'count'], ascending=False)
            b_data = b_data.drop_duplicates(subset=['Origin_Airport', 'Destination_Airport', 'Airline'], keep='first')

            b_data = b_data.set_index(['Origin_Airport', 'Destination_Airport', 'Airline']).drop('count', axis=1)

            b = data[(data['Estimated_Arrival_Time'] == 'nan') & (data['Estimated_Departure_Time'] == 'nan')]
            b = b.set_index(['Origin_Airport', 'Destination_Airport', 'Airline'])

            b[['Estimated_Arrival_Time', 'Estimated_Departure_Time']] = b_data[['Estimated_Arrival_Time', 'Estimated_Departure_Time']]
            
            return b.reset_index()
        
        else:
            print('Where 값을 채워주세요. at: 도착시간 보간, dt: 출발시간 보간')
            return None
            
            
        # 같은 출발/도착시간이 있을 경우 가장 많은 출발/도착시간으로 채움
        merge_data = data.groupby(['Origin_Airport', 'Destination_Airport', 'Airline'])[time2, time1, 'Estimated_Time'].value_counts()
        merge_data = merge_data.reset_index()
        merge_data = merge_data.rename(columns={0:'count'})
        merge_data = merge_data[(merge_data[time1] != 'nan') & (merge_data[time2] != 'nan')]
        merge_data = merge_data.sort_values(['Origin_Airport', 'Destination_Airport', 'Airline', 'count'], ascending=False)
        merge_data = merge_data.drop_duplicates(subset=['Origin_Airport', 'Destination_Airport', 'Airline', time1], keep='first')
        mt = data.loc[(data[time2].isin(['nan'])) & ~(data[time1].isin(['nan'])), ['Origin_Airport', 'Destination_Airport', 'Airline',time2, time1]]
        mt = mt.drop(time2, axis=1)
        mt = pd.merge(mt, merge_data, how='left', on =['Origin_Airport', 'Destination_Airport', 'Airline', time1])
        
        # 같은 출발/도착시간이 없을 경우 출도착공항, 항공사 기준 Estimated_Time이 가장 많은 시간을 채우고 출발/도착시간을 계산
        et = merge_data.groupby(['Origin_Airport', 'Destination_Airport', 'Airline'])[['Estimated_Time']].value_counts()
        et = et.reset_index()
        et = et.rename(columns={0:'count'})
        et = et.sort_values(['Origin_Airport', 'Destination_Airport', 'Airline', 'count'], ascending=False)
        et = et.drop_duplicates(subset=['Origin_Airport', 'Destination_Airport', 'Airline'], keep='first').drop(['count'], axis=1)
        mt2 = mt[mt[time2].isna()].drop(['Estimated_Time', 'count'], axis=1)
        mt2 = pd.merge(mt2, et, how='left', on =['Origin_Airport', 'Destination_Airport', 'Airline'])
        
        # 위 조건에서 Estimated_Time이 없을경우 출도착공항만 고려하여 Estimated_Time이 가장 많은 시간을 채우고 출발/도착시간을 계산
        et2 = merge_data.groupby(['Origin_Airport', 'Destination_Airport'])[['Estimated_Time']].value_counts()
        et2 = et2.reset_index()
        et2 = et2.rename(columns={0:'count'})
        et2 = et2.sort_values(['Origin_Airport', 'Destination_Airport', 'count'], ascending=False)
        et2 = et2.drop_duplicates(subset=['Origin_Airport', 'Destination_Airport'], keep='first').drop(['count'], axis=1)
        mt3= mt2[mt2['Estimated_Time'].isna()].drop(['Estimated_Time'], axis=1)
        mt3 = pd.merge(mt3, et2, how='left', on =['Origin_Airport', 'Destination_Airport'])
        
        # mt3-mt2 합침
        mt= mt.set_index(['Origin_Airport', 'Destination_Airport', 'Airline'])
        mt2= mt2.set_index(['Origin_Airport', 'Destination_Airport'])
        mt3= mt3.set_index(['Origin_Airport', 'Destination_Airport'])
        mt2.loc[mt2['Estimated_Time'].isna(), 'Estimated_Time'] = mt3['Estimated_Time']
        
        # mt2-mt 합침
        mt2= mt2.reset_index().set_index(['Origin_Airport', 'Destination_Airport', 'Airline'])
        mt.loc[mt['Estimated_Time'].isna(), 'Estimated_Time'] = mt2['Estimated_Time']
        
        # mt-data 합침 (따로 분리하여 나중에 한번에 채움. 보간한 값을 보간할 때 사용하지 않기 위함)
        mt = mt.drop('count', axis=1).reset_index().set_index(['Origin_Airport', 'Destination_Airport', 'Airline', time1])
        fill_data = data[(data[time1] != 'nan') & (data[time2] == 'nan')]
        fill_data = fill_data.set_index(['Origin_Airport', 'Destination_Airport', 'Airline', time1])
        fill_data[[time2, 'Estimated_Time']] = mt[[time2, 'Estimated_Time']]
        fill_data = fill_data.reset_index()
        
        return fill_data   
        
        
        
    
    # 시간 채우는 함수
    def fill_time(self, data, where = None):
        at_data = self.fill_timedata(data, where='at')
        dt_data = self.fill_timedata(data, where='dt')
        b_data = self.fill_timedata(data, where='both')

        data = data.set_index('ID')
        at_data = at_data.set_index('ID')
        dt_data = dt_data.set_index('ID')
        b_data = b_data.set_index('ID')
        
        data.loc[(data['Estimated_Arrival_Time'] == 'nan') & (data['Estimated_Departure_Time'] != 'nan'), ['Estimated_Arrival_Time', 'Estimated_Time']] = at_data[['Estimated_Arrival_Time', 'Estimated_Time']]
        data.loc[(data['Estimated_Departure_Time'] == 'nan')  & (data['Estimated_Arrival_Time'] != 'nan'), ['Estimated_Departure_Time', 'Estimated_Time']] = dt_data[['Estimated_Departure_Time', 'Estimated_Time']]
        data.loc[(data['Estimated_Departure_Time'] == 'nan') & (data['Estimated_Arrival_Time'] == 'nan'), ['Estimated_Departure_Time', 'Estimated_Arrival_Time', 'Estimated_Time']] = b_data[['Estimated_Departure_Time', 'Estimated_Arrival_Time', 'Estimated_Time']]
        data['Estimated_Departure_Time'] = data['Estimated_Departure_Time'].fillna(9999).astype(int).astype(str)
        data['Estimated_Departure_Time'] = data['Estimated_Departure_Time'].str.zfill(4)
        data['Estimated_Arrival_Time'] = data['Estimated_Arrival_Time'].fillna(9999).astype(int).astype(str)
        data['Estimated_Arrival_Time'] = data['Estimated_Arrival_Time'].str.zfill(4)
        
        # apply용 함수
        def arr_time(x):
            try:
                x['Estimated_Departure_Time'] = x['Estimated_Departure_Time'].replace('2400','0000')
                time = datetime.strptime(x['Estimated_Departure_Time'], "%H%M") + timedelta(minutes=x['Estimated_Time'])
                hour = str(time.hour)
                minute = str(time.minute)
                x['Estimated_Arrival_Time'] = hour+minute       
            except:
                pass
            
            return x
        
        def dep_time(x):
            try:
                x['Estimated_Arrival_Time'] = x['Estimated_Arrival_Time'].replace('2400','0000')
                time = datetime.strptime(x['Estimated_Arrival_Time'], "%H%M") + timedelta(minutes=x['Estimated_Time'])
                hour = str(time.hour)
                minute = str(time.minute)
                x['Estimated_Departure_Time'] = hour+minute       
            except:
                pass
            
            return x
        
        add_time = data.loc[(data['Estimated_Arrival_Time'] == '9999') & (data['Estimated_Departure_Time'] != '9999'), ['Estimated_Departure_Time', 'Estimated_Time', 'Estimated_Arrival_Time']]
        t = add_time.apply(arr_time, axis=1)
        t= t[~t['Estimated_Time'].isna()]
        data.loc[t.index, 'Estimated_Arrival_Time'] = t['Estimated_Arrival_Time']
        
        add_time = data.loc[(data['Estimated_Arrival_Time'] != '9999') & (data['Estimated_Departure_Time'] == '9999'), ['Estimated_Arrival_Time', 'Estimated_Time', 'Estimated_Departure_Time']]
        t = add_time.apply(dep_time, axis=1)
        t= t[~t['Estimated_Time'].isna()]
        data.loc[t.index, 'Estimated_Departure_Time'] = t['Estimated_Departure_Time']
        
        if where == 'test':
            test = data[~data['Estimated_Time'].isna()]
            test = data[data['Estimated_Time'] != 'nan']
            
            return test, data
            

        data = data[~data['Estimated_Time'].isna()]
        data = data[data['Estimated_Time'] != 'nan']

        
        return data
    
    def train_processing(self):
        data = self.fill_airline_and_id(self.x)
        data = self.fill_state(data)
        data = self.to_time(data, where='first')
        data = self.fill_airline_and_id_2(data)
        data = self.fill_time(data)
        data = self.to_time(data, where='twice')
        
        
        return data
    
    
    def test_processing(self):
        data = self.fill_airline_and_id(self.test)
        data = self.fill_state(data)
        data = self.to_time(data, where='first')
        data = self.fill_airline_and_id_2(data)
        data, origin = self.fill_time(data, where='test')
        data = self.to_time(data, where='twice')
        
    
        return data, origin

# %%
pc = Processing(train, test)

train = pc.train_processing()
test, origin_test = pc.test_processing()
# Out:
# <ipython-input-50-d06091b4e9a9>:226: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   merge_data = data.groupby(['Origin_Airport', 'Destination_Airport', 'Airline'])[time2, time1, 'Estimated_Time'].value_counts()
# <ipython-input-50-d06091b4e9a9>:226: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   merge_data = data.groupby(['Origin_Airport', 'Destination_Airport', 'Airline'])[time2, time1, 'Estimated_Time'].value_counts()
# <ipython-input-50-d06091b4e9a9>:205: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   b_data = b_data.groupby(['Origin_Airport', 'Destination_Airport', 'Airline'])['Estimated_Arrival_Time', 'Estimated_Departure_Time'].value_counts()
# <ipython-input-50-d06091b4e9a9>:226: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   merge_data = data.groupby(['Origin_Airport', 'Destination_Airport', 'Airline'])[time2, time1, 'Estimated_Time'].value_counts()
# <ipython-input-50-d06091b4e9a9>:226: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   merge_data = data.groupby(['Origin_Airport', 'Destination_Airport', 'Airline'])[time2, time1, 'Estimated_Time'].value_counts()
# <ipython-input-50-d06091b4e9a9>:205: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   b_data = b_data.groupby(['Origin_Airport', 'Destination_Airport', 'Airline'])['Estimated_Arrival_Time', 'Estimated_Departure_Time'].value_counts()

# %%
test = test[~test['Estimated_Departure_Time'].isin(['1557'])]
test = test[~test['Estimated_Arrival_Time'].isin(['1557'])]

# %%
def FE(x):
    x = x.drop(['NAME','NAME2', 'Carrier_Code(IATA)', 'Cancelled', 'Diverted', 'Estimated_Departure_Time', 'Estimated_Arrival_Time'], axis=1)
    x['edt_h'] = x['Estimated_Departure_Time_HH:MM'].apply(lambda x:int(x.split(':')[0]))
    x['edt_m'] = x['Estimated_Departure_Time_HH:MM'].apply(lambda x:int(x.split(':')[1]))
    x['eat_h'] = x['Estimated_Arrival_Time_HH:MM'].apply(lambda x:int(x.split(':')[0]))
    x['eat_m'] = x['Estimated_Arrival_Time_HH:MM'].apply(lambda x:int(x.split(':')[1]))

    x = x.drop(['Estimated_Departure_Time_HH:MM', 'Estimated_Arrival_Time_HH:MM'], axis=1)
    
    return x

train = FE(train)
test = FE(test)

# %%
from sklearn.preprocessing import LabelEncoder
train_ar = train.__deepcopy__()
test_ar = test.__deepcopy__()

label_st = train_ar.drop(columns = ['Delay'])
train_st = train_ar[(train_ar['Delay'].astype(str) != 'nan')].drop(columns = ['Delay'])
X_nan = train_ar[(train_ar['Delay'].astype(str) == 'nan')].drop(columns = ['Delay'])

qual_col = ['Origin_Airport', 'Origin_State', 'Destination_Airport', 'Destination_State', 'Airline', 'Carrier_ID(DOT)', 'Tail_Number', 'Dep_time_gb',	'Arr_time_gb',	'route_gb']

for i in qual_col:
    le = LabelEncoder()
    le=le.fit(label_st[i])
    for label in np.unique(test[i].dropna()):
        if label not in le.classes_: 
            le.classes_ = np.append(le.classes_, label)
    train_ar[i] = le.transform(train_ar[i])
    train_st[i]=le.transform(train_st[i])
    X_nan[i]=le.transform(X_nan[i])
    test_ar[i]=le.transform(test_ar[i])

# %%
from sklearn.semi_supervised import SelfTrainingClassifier
from sklearn.ensemble import RandomForestClassifier

X = train_st
y = train_ar[(train_ar['Delay'].astype(str) != 'nan')]['Delay']

stclf = SelfTrainingClassifier(
    base_estimator = RandomForestClassifier(n_estimators = 100),
    verbose = True)

stclf.fit(X, y)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/semi_supervised/_self_training.py:212: UserWarning: y contains no unlabeled samples
#   warnings.warn("y contains no unlabeled samples", UserWarning)
# SelfTrainingClassifier(base_estimator=RandomForestClassifier(), verbose=True)

# %%
X_nan['Delay_pred'] = stclf.predict(X_nan)

# %%
X_nan['Delay_pred']
# Out:
# ID
# TRAIN_000001    Not_Delayed
# TRAIN_000002    Not_Delayed
# TRAIN_000003    Not_Delayed
# TRAIN_000004    Not_Delayed
# TRAIN_000007    Not_Delayed
#                    ...
# TRAIN_999995    Not_Delayed
# TRAIN_999996    Not_Delayed
# TRAIN_999997    Not_Delayed
# TRAIN_999998    Not_Delayed
# TRAIN_999999    Not_Delayed
# Name: Delay_pred, Length: 736317, dtype: object

# %%
train_ar.loc[train_ar['Delay'] == 'nan', 'Delay'] = X_nan['Delay_pred']

# %%
train_ar['Delay'].unique()
# Out:
# array(['Not_Delayed', 'Delayed'], dtype=object)

# %%
train_ar = train_ar.reset_index()
map = {
    'Not_Delayed' :    0,
    'Delayed'    :    1, 
}
train_ar['Delay'] = train_ar.Delay.map(map)

# %%
X_train = train_ar.drop(columns = ['ID','Delay'], axis=1)
y_train = train_ar['Delay']
x_test = test_ar

# %%
from catboost import CatBoostClassifier

clf = CatBoostClassifier()
clf.fit(X_train, y_train)
# Out:
# Learning rate set to 0.195771
# 0:	learn: 0.5092250	total: 209ms	remaining: 3m 29s
# 1:	learn: 0.4050830	total: 378ms	remaining: 3m 8s
# 2:	learn: 0.3466270	total: 542ms	remaining: 3m
# 3:	learn: 0.3126972	total: 694ms	remaining: 2m 52s
# 4:	learn: 0.2918495	total: 864ms	remaining: 2m 51s
# 5:	learn: 0.2800379	total: 1.02s	remaining: 2m 49s
# 6:	learn: 0.2722140	total: 1.18s	remaining: 2m 47s
# 7:	learn: 0.2671408	total: 1.34s	remaining: 2m 45s
# 8:	learn: 0.2642175	total: 1.48s	remaining: 2m 43s
# 9:	learn: 0.2617419	total: 1.65s	remaining: 2m 43s
# 10:	learn: 0.2601569	total: 1.79s	remaining: 2m 40s
# 11:	learn: 0.2590381	total: 1.95s	remaining: 2m 40s
# 12:	learn: 0.2583312	total: 2.12s	remaining: 2m 40s
# 13:	learn: 0.2576898	total: 2.26s	remaining: 2m 39s
# 14:	learn: 0.2571108	total: 2.44s	remaining: 2m 40s
# 15:	learn: 0.2567886	total: 2.57s	remaining: 2m 38s
# 16:	learn: 0.2565169	total: 2.74s	remaining: 2m 38s
# 17:	learn: 0.2562259	total: 2.89s	remaining: 2m 37s
# 18:	learn: 0.2559067	total: 3.05s	remaining: 2m 37s
# 19:	learn: 0.2554800	total: 3.21s	remaining: 2m 37s
# 20:	learn: 0.2553005	total: 3.37s	remaining: 2m 37s
# 21:	learn: 0.2551163	total: 3.51s	remaining: 2m 35s
# 22:	learn: 0.2549975	total: 3.66s	remaining: 2m 35s
# 23:	learn: 0.2548388	total: 3.81s	remaining: 2m 34s
# 24:	learn: 0.2546968	total: 3.97s	remaining: 2m 34s
# 25:	learn: 0.2545307	total: 4.12s	remaining: 2m 34s
# 26:	learn: 0.2544062	total: 4.28s	remaining: 2m 34s
# 27:	learn: 0.2541536	total: 4.45s	remaining: 2m 34s
# 28:	learn: 0.2540221	total: 4.6s	remaining: 2m 34s
# 29:	learn: 0.2538434	total: 4.75s	remaining: 2m 33s
# 30:	learn: 0.2537362	total: 4.91s	remaining: 2m 33s
# 31:	learn: 0.2535482	total: 5.07s	remaining: 2m 33s
# 32:	learn: 0.2534146	total: 5.24s	remaining: 2m 33s
# 33:	learn: 0.2533403	total: 5.4s	remaining: 2m 33s
# 34:	learn: 0.2532624	total: 5.54s	remaining: 2m 32s
# 35:	learn: 0.2531257	total: 5.79s	remaining: 2m 35s
# 36:	learn: 0.2530032	total: 6.08s	remaining: 2m 38s
# 37:	learn: 0.2528655	total: 6.37s	remaining: 2m 41s
# 38:	learn: 0.2528054	total: 6.61s	remaining: 2m 42s
# 39:	learn: 0.2526818	total: 6.95s	remaining: 2m 46s
# 40:	learn: 0.2525883	total: 7.24s	remaining: 2m 49s
# 41:	learn: 0.2525014	total: 7.53s	remaining: 2m 51s
# 42:	learn: 0.2523838	total: 7.8s	remaining: 2m 53s
# 43:	learn: 0.2522510	total: 8.13s	remaining: 2m 56s
# 44:	learn: 0.2521837	total: 8.4s	remaining: 2m 58s
# 45:	learn: 0.2521113	total: 8.69s	remaining: 3m
# 46:	learn: 0.2520153	total: 8.85s	remaining: 2m 59s
# 47:	learn: 0.2519189	total: 9.01s	remaining: 2m 58s
# 48:	learn: 0.2518335	total: 9.16s	remaining: 2m 57s
# 49:	learn: 0.2517824	total: 9.3s	remaining: 2m 56s
# 50:	learn: 0.2517117	total: 9.45s	remaining: 2m 55s
# 51:	learn: 0.2516632	total: 9.61s	remaining: 2m 55s
# 52:	learn: 0.2515998	total: 9.77s	remaining: 2m 54s
# 53:	learn: 0.2515277	total: 9.93s	remaining: 2m 54s
# 54:	learn: 0.2514450	total: 10.1s	remaining: 2m 53s
# 55:	learn: 0.2513473	total: 10.3s	remaining: 2m 52s
# 56:	learn: 0.2512630	total: 10.4s	remaining: 2m 52s
# 57:	learn: 0.2511902	total: 10.6s	remaining: 2m 51s
# 58:	learn: 0.2511269	total: 10.7s	remaining: 2m 50s
# 59:	learn: 0.2510108	total: 10.9s	remaining: 2m 50s
# 60:	learn: 0.2509427	total: 11s	remaining: 2m 49s
# 61:	learn: 0.2508701	total: 11.1s	remaining: 2m 48s
# 62:	learn: 0.2507816	total: 11.3s	remaining: 2m 48s
# 63:	learn: 0.2507080	total: 11.5s	remaining: 2m 47s
# 64:	learn: 0.2506281	total: 11.6s	remaining: 2m 47s
# 65:	learn: 0.2505730	total: 11.8s	remaining: 2m 46s
# 66:	learn: 0.2504951	total: 11.9s	remaining: 2m 46s
# 67:	learn: 0.2504232	total: 12.1s	remaining: 2m 45s
# 68:	learn: 0.2503834	total: 12.2s	remaining: 2m 45s
# 69:	learn: 0.2503467	total: 12.4s	remaining: 2m 44s
# 70:	learn: 0.2502615	total: 12.5s	remaining: 2m 44s
# 71:	learn: 0.2502050	total: 12.7s	remaining: 2m 43s
# 72:	learn: 0.2501391	total: 12.8s	remaining: 2m 43s
# 73:	learn: 0.2500622	total: 13s	remaining: 2m 42s
# 74:	learn: 0.2499832	total: 13.2s	remaining: 2m 42s
# 75:	learn: 0.2499280	total: 13.3s	remaining: 2m 41s
# 76:	learn: 0.2498868	total: 13.4s	remaining: 2m 41s
# 77:	learn: 0.2498427	total: 13.6s	remaining: 2m 40s
# 78:	learn: 0.2497906	total: 13.8s	remaining: 2m 40s
# 79:	learn: 0.2497265	total: 13.9s	remaining: 2m 40s
# 80:	learn: 0.2496663	total: 14.1s	remaining: 2m 40s
# 81:	learn: 0.2496084	total: 14.3s	remaining: 2m 39s
# 82:	learn: 0.2495545	total: 14.4s	remaining: 2m 39s
# 83:	learn: 0.2495149	total: 14.6s	remaining: 2m 38s
# 84:	learn: 0.2494460	total: 14.7s	remaining: 2m 38s
# 85:	learn: 0.2493920	total: 14.9s	remaining: 2m 38s
# 86:	learn: 0.2493306	total: 15s	remaining: 2m 37s
# 87:	learn: 0.2492718	total: 15.2s	remaining: 2m 37s
# 88:	learn: 0.2492174	total: 15.3s	remaining: 2m 36s
# 89:	learn: 0.2491658	total: 15.4s	remaining: 2m 36s
# 90:	learn: 0.2491076	total: 15.6s	remaining: 2m 35s
# 91:	learn: 0.2490544	total: 15.8s	remaining: 2m 35s
# 92:	learn: 0.2489873	total: 15.9s	remaining: 2m 35s
# 93:	learn: 0.2489452	total: 16.1s	remaining: 2m 35s
# 94:	learn: 0.2488900	total: 16.2s	remaining: 2m 34s
# 95:	learn: 0.2488428	total: 16.4s	remaining: 2m 34s
# 96:	learn: 0.2487999	total: 16.6s	remaining: 2m 34s
# 97:	learn: 0.2487321	total: 16.7s	remaining: 2m 33s
# 98:	learn: 0.2486899	total: 16.9s	remaining: 2m 33s
# 99:	learn: 0.2486267	total: 17s	remaining: 2m 33s
# 100:	learn: 0.2485841	total: 17.2s	remaining: 2m 32s
# 101:	learn: 0.2485260	total: 17.3s	remaining: 2m 32s
# 102:	learn: 0.2484652	total: 17.5s	remaining: 2m 32s
# 103:	learn: 0.2483993	total: 17.6s	remaining: 2m 31s
# 104:	learn: 0.2483570	total: 17.8s	remaining: 2m 31s
# 105:	learn: 0.2482967	total: 17.9s	remaining: 2m 31s
# 106:	learn: 0.2482490	total: 18.1s	remaining: 2m 30s
# 107:	learn: 0.2482015	total: 18.2s	remaining: 2m 30s
# 108:	learn: 0.2481536	total: 18.4s	remaining: 2m 30s
# 109:	learn: 0.2480949	total: 18.5s	remaining: 2m 29s
# 110:	learn: 0.2480557	total: 18.7s	remaining: 2m 29s
# 111:	learn: 0.2480329	total: 18.9s	remaining: 2m 29s
# 112:	learn: 0.2479766	total: 19.2s	remaining: 2m 30s
# 113:	learn: 0.2479228	total: 19.4s	remaining: 2m 31s
# 114:	learn: 0.2478584	total: 19.7s	remaining: 2m 31s
# 115:	learn: 0.2478158	total: 19.9s	remaining: 2m 31s
# 116:	learn: 0.2477706	total: 20.2s	remaining: 2m 32s
# 117:	learn: 0.2477337	total: 20.5s	remaining: 2m 33s
# 118:	learn: 0.2476744	total: 20.8s	remaining: 2m 34s
# 119:	learn: 0.2476289	total: 21.1s	remaining: 2m 35s
# 120:	learn: 0.2475856	total: 21.4s	remaining: 2m 35s
# 121:	learn: 0.2475527	total: 21.7s	remaining: 2m 36s
# 122:	learn: 0.2474882	total: 21.9s	remaining: 2m 36s
# 123:	learn: 0.2474361	total: 22s	remaining: 2m 35s
# 124:	learn: 0.2473901	total: 22.2s	remaining: 2m 35s
# 125:	learn: 0.2473523	total: 22.4s	remaining: 2m 35s
# 126:	learn: 0.2473029	total: 22.5s	remaining: 2m 34s
# 127:	learn: 0.2472637	total: 22.7s	remaining: 2m 34s
# 128:	learn: 0.2472063	total: 22.8s	remaining: 2m 34s
# 129:	learn: 0.2471416	total: 23s	remaining: 2m 33s
# 130:	learn: 0.2470806	total: 23.1s	remaining: 2m 33s
# 131:	learn: 0.2470558	total: 23.3s	remaining: 2m 32s
# 132:	learn: 0.2470218	total: 23.4s	remaining: 2m 32s
# 133:	learn: 0.2469762	total: 23.6s	remaining: 2m 32s
# 134:	learn: 0.2469300	total: 23.7s	remaining: 2m 31s
# 135:	learn: 0.2468985	total: 23.9s	remaining: 2m 31s
# 136:	learn: 0.2468387	total: 24s	remaining: 2m 31s
# 137:	learn: 0.2467993	total: 24.2s	remaining: 2m 30s
# 138:	learn: 0.2467668	total: 24.3s	remaining: 2m 30s
# 139:	learn: 0.2467301	total: 24.5s	remaining: 2m 30s
# 140:	learn: 0.2466831	total: 24.6s	remaining: 2m 30s
# 141:	learn: 0.2466408	total: 24.8s	remaining: 2m 29s
# 142:	learn: 0.2465950	total: 24.9s	remaining: 2m 29s
# 143:	learn: 0.2465502	total: 25.1s	remaining: 2m 29s
# 144:	learn: 0.2465211	total: 25.2s	remaining: 2m 28s
# 145:	learn: 0.2464910	total: 25.4s	remaining: 2m 28s
# 146:	learn: 0.2464482	total: 25.5s	remaining: 2m 27s
# 147:	learn: 0.2464198	total: 25.6s	remaining: 2m 27s
# 148:	learn: 0.2463677	total: 25.8s	remaining: 2m 27s
# 149:	learn: 0.2463188	total: 26s	remaining: 2m 27s
# 150:	learn: 0.2462686	total: 26.1s	remaining: 2m 26s
# 151:	learn: 0.2462240	total: 26.3s	remaining: 2m 26s
# 152:	learn: 0.2461871	total: 26.4s	remaining: 2m 26s
# 153:	learn: 0.2461436	total: 26.6s	remaining: 2m 26s
# 154:	learn: 0.2461030	total: 26.7s	remaining: 2m 25s
# 155:	learn: 0.2460484	total: 26.9s	remaining: 2m 25s
# 156:	learn: 0.2459917	total: 27.1s	remaining: 2m 25s
# 157:	learn: 0.2459617	total: 27.2s	remaining: 2m 25s
# 158:	learn: 0.2459148	total: 27.4s	remaining: 2m 24s
# 159:	learn: 0.2458800	total: 27.5s	remaining: 2m 24s
# 160:	learn: 0.2458309	total: 27.7s	remaining: 2m 24s
# 161:	learn: 0.2457985	total: 27.9s	remaining: 2m 24s
# 162:	learn: 0.2457514	total: 28s	remaining: 2m 23s
# 163:	learn: 0.2457269	total: 28.2s	remaining: 2m 23s
# 164:	learn: 0.2456852	total: 28.3s	remaining: 2m 23s
# 165:	learn: 0.2456570	total: 28.5s	remaining: 2m 23s
# 166:	learn: 0.2456065	total: 28.6s	remaining: 2m 22s
# 167:	learn: 0.2455550	total: 28.8s	remaining: 2m 22s
# 168:	learn: 0.2455197	total: 28.9s	remaining: 2m 22s
# 169:	learn: 0.2454809	total: 29.1s	remaining: 2m 21s
# 170:	learn: 0.2454402	total: 29.2s	remaining: 2m 21s
# 171:	learn: 0.2453983	total: 29.4s	remaining: 2m 21s
# 172:	learn: 0.2453530	total: 29.5s	remaining: 2m 21s
# 173:	learn: 0.2453305	total: 29.7s	remaining: 2m 20s
# 174:	learn: 0.2452908	total: 29.8s	remaining: 2m 20s
# 175:	learn: 0.2452611	total: 30s	remaining: 2m 20s
# 176:	learn: 0.2452201	total: 30.1s	remaining: 2m 20s
# 177:	learn: 0.2451884	total: 30.3s	remaining: 2m 19s
# 178:	learn: 0.2451549	total: 30.4s	remaining: 2m 19s
# 179:	learn: 0.2451211	total: 30.6s	remaining: 2m 19s
# 180:	learn: 0.2450898	total: 30.7s	remaining: 2m 18s
# 181:	learn: 0.2450359	total: 30.9s	remaining: 2m 18s
# 182:	learn: 0.2450001	total: 31s	remaining: 2m 18s
# 183:	learn: 0.2449521	total: 31.2s	remaining: 2m 18s
# 184:	learn: 0.2449032	total: 31.3s	remaining: 2m 18s
# 185:	learn: 0.2448572	total: 31.5s	remaining: 2m 17s
# 186:	learn: 0.2448174	total: 31.6s	remaining: 2m 17s
# 187:	learn: 0.2447913	total: 31.8s	remaining: 2m 17s
# 188:	learn: 0.2447684	total: 32.1s	remaining: 2m 17s
# 189:	learn: 0.2447240	total: 32.3s	remaining: 2m 17s
# 190:	learn: 0.2446832	total: 32.6s	remaining: 2m 18s
# 191:	learn: 0.2446591	total: 32.9s	remaining: 2m 18s
# 192:	learn: 0.2446304	total: 33.2s	remaining: 2m 18s
# 193:	learn: 0.2445906	total: 33.5s	remaining: 2m 19s
# 194:	learn: 0.2445522	total: 33.8s	remaining: 2m 19s
# 195:	learn: 0.2445149	total: 34.1s	remaining: 2m 19s
# 196:	learn: 0.2444858	total: 34.4s	remaining: 2m 20s
# 197:	learn: 0.2444565	total: 34.7s	remaining: 2m 20s
# 198:	learn: 0.2444095	total: 34.9s	remaining: 2m 20s
# 199:	learn: 0.2443681	total: 35s	remaining: 2m 20s
# 200:	learn: 0.2443345	total: 35.2s	remaining: 2m 19s
# 201:	learn: 0.2442881	total: 35.4s	remaining: 2m 19s
# 202:	learn: 0.2442491	total: 35.5s	remaining: 2m 19s
# 203:	learn: 0.2442271	total: 35.6s	remaining: 2m 19s
# 204:	learn: 0.2441906	total: 35.8s	remaining: 2m 18s
# 205:	learn: 0.2441555	total: 35.9s	remaining: 2m 18s
# 206:	learn: 0.2441269	total: 36.1s	remaining: 2m 18s
# 207:	learn: 0.2440903	total: 36.3s	remaining: 2m 18s
# 208:	learn: 0.2440655	total: 36.4s	remaining: 2m 17s
# 209:	learn: 0.2440364	total: 36.6s	remaining: 2m 17s
# 210:	learn: 0.2440073	total: 36.7s	remaining: 2m 17s
# 211:	learn: 0.2439624	total: 36.9s	remaining: 2m 17s
# 212:	learn: 0.2439395	total: 37s	remaining: 2m 16s
# 213:	learn: 0.2439030	total: 37.2s	remaining: 2m 16s
# 214:	learn: 0.2438596	total: 37.3s	remaining: 2m 16s
# 215:	learn: 0.2438254	total: 37.5s	remaining: 2m 15s
# 216:	learn: 0.2437872	total: 37.6s	remaining: 2m 15s
# 217:	learn: 0.2437521	total: 37.8s	remaining: 2m 15s
# 218:	learn: 0.2437197	total: 37.9s	remaining: 2m 15s
# 219:	learn: 0.2436674	total: 38.1s	remaining: 2m 15s
# 220:	learn: 0.2436449	total: 38.2s	remaining: 2m 14s
# 221:	learn: 0.2436084	total: 38.4s	remaining: 2m 14s
# 222:	learn: 0.2435694	total: 38.5s	remaining: 2m 14s
# 223:	learn: 0.2435349	total: 38.7s	remaining: 2m 14s
# 224:	learn: 0.2435081	total: 38.8s	remaining: 2m 13s
# 225:	learn: 0.2434850	total: 39s	remaining: 2m 13s
# 226:	learn: 0.2434447	total: 39.1s	remaining: 2m 13s
# 227:	learn: 0.2434118	total: 39.3s	remaining: 2m 13s
# 228:	learn: 0.2433736	total: 39.4s	remaining: 2m 12s
# 229:	learn: 0.2433396	total: 39.6s	remaining: 2m 12s
# 230:	learn: 0.2433130	total: 39.8s	remaining: 2m 12s
# 231:	learn: 0.2432752	total: 39.9s	remaining: 2m 12s
# 232:	learn: 0.2432488	total: 40.1s	remaining: 2m 11s
# 233:	learn: 0.2432157	total: 40.2s	remaining: 2m 11s
# 234:	learn: 0.2431813	total: 40.4s	remaining: 2m 11s
# 235:	learn: 0.2431535	total: 40.5s	remaining: 2m 11s
# 236:	learn: 0.2431133	total: 40.7s	remaining: 2m 10s
# 237:	learn: 0.2430764	total: 40.8s	remaining: 2m 10s
# 238:	learn: 0.2430547	total: 41s	remaining: 2m 10s
# 239:	learn: 0.2430244	total: 41.1s	remaining: 2m 10s
# 240:	learn: 0.2429926	total: 41.3s	remaining: 2m 9s
# 241:	learn: 0.2429546	total: 41.4s	remaining: 2m 9s
# 242:	learn: 0.2429249	total: 41.6s	remaining: 2m 9s
# 243:	learn: 0.2428982	total: 41.7s	remaining: 2m 9s
# 244:	learn: 0.2428761	total: 41.9s	remaining: 2m 8s
# 245:	learn: 0.2428540	total: 42s	remaining: 2m 8s
# 246:	learn: 0.2428201	total: 42.2s	remaining: 2m 8s
# 247:	learn: 0.2427873	total: 42.3s	remaining: 2m 8s
# 248:	learn: 0.2427539	total: 42.5s	remaining: 2m 8s
# 249:	learn: 0.2427320	total: 42.6s	remaining: 2m 7s
# 250:	learn: 0.2427113	total: 42.8s	remaining: 2m 7s
# 251:	learn: 0.2426730	total: 42.9s	remaining: 2m 7s
# 252:	learn: 0.2426385	total: 43.1s	remaining: 2m 7s
# 253:	learn: 0.2426045	total: 43.2s	remaining: 2m 7s
# 254:	learn: 0.2425814	total: 43.4s	remaining: 2m 6s
# 255:	learn: 0.2425396	total: 43.5s	remaining: 2m 6s
# 256:	learn: 0.2425109	total: 43.7s	remaining: 2m 6s
# 257:	learn: 0.2424871	total: 43.9s	remaining: 2m 6s
# 258:	learn: 0.2424499	total: 44s	remaining: 2m 5s
# 259:	learn: 0.2424192	total: 44.1s	remaining: 2m 5s
# 260:	learn: 0.2423820	total: 44.3s	remaining: 2m 5s
# 261:	learn: 0.2423534	total: 44.4s	remaining: 2m 5s
# 262:	learn: 0.2423131	total: 44.6s	remaining: 2m 4s
# 263:	learn: 0.2422751	total: 44.8s	remaining: 2m 4s
# 264:	learn: 0.2422503	total: 45s	remaining: 2m 4s
# 265:	learn: 0.2422310	total: 45.3s	remaining: 2m 4s
# 266:	learn: 0.2422032	total: 45.6s	remaining: 2m 5s
# 267:	learn: 0.2421783	total: 45.9s	remaining: 2m 5s
# 268:	learn: 0.2421391	total: 46.2s	remaining: 2m 5s
# 269:	learn: 0.2421152	total: 46.5s	remaining: 2m 5s
# 270:	learn: 0.2420861	total: 46.8s	remaining: 2m 5s
# 271:	learn: 0.2420569	total: 47.1s	remaining: 2m 6s
# 272:	learn: 0.2420283	total: 47.4s	remaining: 2m 6s
# 273:	learn: 0.2419988	total: 47.7s	remaining: 2m 6s
# 274:	learn: 0.2419641	total: 47.9s	remaining: 2m 6s
# 275:	learn: 0.2419469	total: 48s	remaining: 2m 5s
# 276:	learn: 0.2419065	total: 48.2s	remaining: 2m 5s
# 277:	learn: 0.2418780	total: 48.3s	remaining: 2m 5s
# 278:	learn: 0.2418461	total: 48.5s	remaining: 2m 5s
# 279:	learn: 0.2418157	total: 48.6s	remaining: 2m 5s
# 280:	learn: 0.2417836	total: 48.8s	remaining: 2m 4s
# 281:	learn: 0.2417567	total: 48.9s	remaining: 2m 4s
# 282:	learn: 0.2417263	total: 49.1s	remaining: 2m 4s
# 283:	learn: 0.2417034	total: 49.2s	remaining: 2m 4s
# 284:	learn: 0.2416850	total: 49.4s	remaining: 2m 3s
# 285:	learn: 0.2416474	total: 49.5s	remaining: 2m 3s
# 286:	learn: 0.2416178	total: 49.7s	remaining: 2m 3s
# 287:	learn: 0.2415895	total: 49.8s	remaining: 2m 3s
# 288:	learn: 0.2415578	total: 50s	remaining: 2m 2s
# 289:	learn: 0.2415251	total: 50.1s	remaining: 2m 2s
# 290:	learn: 0.2414864	total: 50.3s	remaining: 2m 2s
# 291:	learn: 0.2414683	total: 50.5s	remaining: 2m 2s
# 292:	learn: 0.2414429	total: 50.6s	remaining: 2m 2s
# 293:	learn: 0.2414114	total: 50.8s	remaining: 2m 1s
# 294:	learn: 0.2413810	total: 50.9s	remaining: 2m 1s
# 295:	learn: 0.2413543	total: 51.1s	remaining: 2m 1s
# 296:	learn: 0.2413329	total: 51.2s	remaining: 2m 1s
# 297:	learn: 0.2413069	total: 51.4s	remaining: 2m
# 298:	learn: 0.2412867	total: 51.5s	remaining: 2m
# 299:	learn: 0.2412669	total: 51.7s	remaining: 2m
# 300:	learn: 0.2412402	total: 51.8s	remaining: 2m
# 301:	learn: 0.2412239	total: 52s	remaining: 2m
# 302:	learn: 0.2412002	total: 52.1s	remaining: 1m 59s
# 303:	learn: 0.2411509	total: 52.3s	remaining: 1m 59s
# 304:	learn: 0.2411336	total: 52.4s	remaining: 1m 59s
# 305:	learn: 0.2411050	total: 52.6s	remaining: 1m 59s
# 306:	learn: 0.2410832	total: 52.7s	remaining: 1m 59s
# 307:	learn: 0.2410595	total: 52.9s	remaining: 1m 58s
# 308:	learn: 0.2410152	total: 53s	remaining: 1m 58s
# 309:	learn: 0.2409885	total: 53.2s	remaining: 1m 58s
# 310:	learn: 0.2409542	total: 53.3s	remaining: 1m 58s
# 311:	learn: 0.2409175	total: 53.5s	remaining: 1m 57s
# 312:	learn: 0.2408944	total: 53.6s	remaining: 1m 57s
# 313:	learn: 0.2408732	total: 53.8s	remaining: 1m 57s
# 314:	learn: 0.2408458	total: 53.9s	remaining: 1m 57s
# 315:	learn: 0.2408245	total: 54.1s	remaining: 1m 57s
# 316:	learn: 0.2407856	total: 54.2s	remaining: 1m 56s
# 317:	learn: 0.2407660	total: 54.4s	remaining: 1m 56s
# 318:	learn: 0.2407495	total: 54.6s	remaining: 1m 56s
# 319:	learn: 0.2407286	total: 54.7s	remaining: 1m 56s
# 320:	learn: 0.2406919	total: 54.9s	remaining: 1m 56s
# 321:	learn: 0.2406684	total: 55s	remaining: 1m 55s
# 322:	learn: 0.2406334	total: 55.2s	remaining: 1m 55s
# 323:	learn: 0.2405927	total: 55.3s	remaining: 1m 55s
# 324:	learn: 0.2405689	total: 55.5s	remaining: 1m 55s
# 325:	learn: 0.2405392	total: 55.6s	remaining: 1m 55s
# 326:	learn: 0.2405056	total: 55.8s	remaining: 1m 54s
# 327:	learn: 0.2404678	total: 55.9s	remaining: 1m 54s
# 328:	learn: 0.2404445	total: 56.1s	remaining: 1m 54s
# 329:	learn: 0.2404067	total: 56.2s	remaining: 1m 54s
# 330:	learn: 0.2403700	total: 56.4s	remaining: 1m 53s
# 331:	learn: 0.2403322	total: 56.5s	remaining: 1m 53s
# 332:	learn: 0.2403062	total: 56.7s	remaining: 1m 53s
# 333:	learn: 0.2402737	total: 56.8s	remaining: 1m 53s
# 334:	learn: 0.2402405	total: 57s	remaining: 1m 53s
# 335:	learn: 0.2402091	total: 57.1s	remaining: 1m 52s
# 336:	learn: 0.2401733	total: 57.3s	remaining: 1m 52s
# 337:	learn: 0.2401568	total: 57.4s	remaining: 1m 52s
# 338:	learn: 0.2401350	total: 57.6s	remaining: 1m 52s
# 339:	learn: 0.2401109	total: 57.8s	remaining: 1m 52s
# 340:	learn: 0.2400708	total: 58.1s	remaining: 1m 52s
# 341:	learn: 0.2400365	total: 58.4s	remaining: 1m 52s
# 342:	learn: 0.2400126	total: 58.7s	remaining: 1m 52s
# 343:	learn: 0.2399871	total: 59s	remaining: 1m 52s
# 344:	learn: 0.2399666	total: 59.3s	remaining: 1m 52s
# 345:	learn: 0.2399366	total: 59.6s	remaining: 1m 52s
# 346:	learn: 0.2399100	total: 59.9s	remaining: 1m 52s
# 347:	learn: 0.2398902	total: 1m	remaining: 1m 52s
# 348:	learn: 0.2398638	total: 1m	remaining: 1m 52s
# 349:	learn: 0.2398398	total: 1m	remaining: 1m 52s
# 350:	learn: 0.2398103	total: 1m	remaining: 1m 52s
# 351:	learn: 0.2397792	total: 1m 1s	remaining: 1m 52s
# 352:	learn: 0.2397521	total: 1m 1s	remaining: 1m 52s
# 353:	learn: 0.2397334	total: 1m 1s	remaining: 1m 52s
# 354:	learn: 0.2396944	total: 1m 1s	remaining: 1m 51s
# 355:	learn: 0.2396665	total: 1m 1s	remaining: 1m 51s
# 356:	learn: 0.2396362	total: 1m 1s	remaining: 1m 51s
# 357:	learn: 0.2396026	total: 1m 1s	remaining: 1m 51s
# 358:	learn: 0.2395788	total: 1m 2s	remaining: 1m 50s
# 359:	learn: 0.2395509	total: 1m 2s	remaining: 1m 50s
# 360:	learn: 0.2395127	total: 1m 2s	remaining: 1m 50s
# 361:	learn: 0.2394772	total: 1m 2s	remaining: 1m 50s
# 362:	learn: 0.2394472	total: 1m 2s	remaining: 1m 50s
# 363:	learn: 0.2394236	total: 1m 2s	remaining: 1m 49s
# 364:	learn: 0.2393943	total: 1m 3s	remaining: 1m 49s
# 365:	learn: 0.2393683	total: 1m 3s	remaining: 1m 49s
# 366:	learn: 0.2393380	total: 1m 3s	remaining: 1m 49s
# 367:	learn: 0.2393058	total: 1m 3s	remaining: 1m 48s
# 368:	learn: 0.2392793	total: 1m 3s	remaining: 1m 48s
# 369:	learn: 0.2392522	total: 1m 3s	remaining: 1m 48s
# 370:	learn: 0.2392180	total: 1m 3s	remaining: 1m 48s
# 371:	learn: 0.2391875	total: 1m 4s	remaining: 1m 48s
# 372:	learn: 0.2391601	total: 1m 4s	remaining: 1m 47s
# 373:	learn: 0.2391364	total: 1m 4s	remaining: 1m 47s
# 374:	learn: 0.2391139	total: 1m 4s	remaining: 1m 47s
# 375:	learn: 0.2390784	total: 1m 4s	remaining: 1m 47s
# 376:	learn: 0.2390513	total: 1m 4s	remaining: 1m 47s
# 377:	learn: 0.2390362	total: 1m 4s	remaining: 1m 46s
# 378:	learn: 0.2390041	total: 1m 5s	remaining: 1m 46s
# 379:	learn: 0.2389802	total: 1m 5s	remaining: 1m 46s
# 380:	learn: 0.2389541	total: 1m 5s	remaining: 1m 46s
# 381:	learn: 0.2389140	total: 1m 5s	remaining: 1m 46s
# 382:	learn: 0.2388922	total: 1m 5s	remaining: 1m 45s
# 383:	learn: 0.2388608	total: 1m 5s	remaining: 1m 45s
# 384:	learn: 0.2388324	total: 1m 6s	remaining: 1m 45s
# 385:	learn: 0.2387934	total: 1m 6s	remaining: 1m 45s
# 386:	learn: 0.2387765	total: 1m 6s	remaining: 1m 45s
# 387:	learn: 0.2387450	total: 1m 6s	remaining: 1m 44s
# 388:	learn: 0.2387209	total: 1m 6s	remaining: 1m 44s
# 389:	learn: 0.2387027	total: 1m 6s	remaining: 1m 44s
# 390:	learn: 0.2386620	total: 1m 6s	remaining: 1m 44s
# 391:	learn: 0.2386435	total: 1m 7s	remaining: 1m 44s
# 392:	learn: 0.2386218	total: 1m 7s	remaining: 1m 43s
# 393:	learn: 0.2385976	total: 1m 7s	remaining: 1m 43s
# 394:	learn: 0.2385758	total: 1m 7s	remaining: 1m 43s
# 395:	learn: 0.2385538	total: 1m 7s	remaining: 1m 43s
# 396:	learn: 0.2385240	total: 1m 7s	remaining: 1m 43s
# 397:	learn: 0.2384939	total: 1m 8s	remaining: 1m 42s
# 398:	learn: 0.2384614	total: 1m 8s	remaining: 1m 42s
# 399:	learn: 0.2384371	total: 1m 8s	remaining: 1m 42s
# 400:	learn: 0.2384082	total: 1m 8s	remaining: 1m 42s
# 401:	learn: 0.2383798	total: 1m 8s	remaining: 1m 42s
# 402:	learn: 0.2383602	total: 1m 8s	remaining: 1m 41s
# 403:	learn: 0.2383391	total: 1m 8s	remaining: 1m 41s
# 404:	learn: 0.2383219	total: 1m 9s	remaining: 1m 41s
# 405:	learn: 0.2382940	total: 1m 9s	remaining: 1m 41s
# 406:	learn: 0.2382734	total: 1m 9s	remaining: 1m 41s
# 407:	learn: 0.2382501	total: 1m 9s	remaining: 1m 40s
# 408:	learn: 0.2382139	total: 1m 9s	remaining: 1m 40s
# 409:	learn: 0.2381936	total: 1m 9s	remaining: 1m 40s
# 410:	learn: 0.2381738	total: 1m 10s	remaining: 1m 40s
# 411:	learn: 0.2381457	total: 1m 10s	remaining: 1m 40s
# 412:	learn: 0.2381037	total: 1m 10s	remaining: 1m 39s
# 413:	learn: 0.2380881	total: 1m 10s	remaining: 1m 39s
# 414:	learn: 0.2380603	total: 1m 10s	remaining: 1m 39s
# 415:	learn: 0.2380355	total: 1m 10s	remaining: 1m 39s
# 416:	learn: 0.2380120	total: 1m 11s	remaining: 1m 39s
# 417:	learn: 0.2379838	total: 1m 11s	remaining: 1m 39s
# 418:	learn: 0.2379591	total: 1m 11s	remaining: 1m 39s
# 419:	learn: 0.2379302	total: 1m 12s	remaining: 1m 39s
# 420:	learn: 0.2378930	total: 1m 12s	remaining: 1m 39s
# 421:	learn: 0.2378704	total: 1m 12s	remaining: 1m 39s
# 422:	learn: 0.2378473	total: 1m 12s	remaining: 1m 39s
# 423:	learn: 0.2378170	total: 1m 13s	remaining: 1m 39s
# 424:	learn: 0.2377896	total: 1m 13s	remaining: 1m 39s
# 425:	learn: 0.2377584	total: 1m 13s	remaining: 1m 39s
# 426:	learn: 0.2377336	total: 1m 13s	remaining: 1m 39s
# 427:	learn: 0.2377101	total: 1m 14s	remaining: 1m 39s
# 428:	learn: 0.2376743	total: 1m 14s	remaining: 1m 38s
# 429:	learn: 0.2376531	total: 1m 14s	remaining: 1m 38s
# 430:	learn: 0.2376260	total: 1m 14s	remaining: 1m 38s
# 431:	learn: 0.2376037	total: 1m 14s	remaining: 1m 38s
# 432:	learn: 0.2375766	total: 1m 14s	remaining: 1m 38s
# 433:	learn: 0.2375586	total: 1m 14s	remaining: 1m 37s
# 434:	learn: 0.2375410	total: 1m 15s	remaining: 1m 37s
# 435:	learn: 0.2375220	total: 1m 15s	remaining: 1m 37s
# 436:	learn: 0.2374966	total: 1m 15s	remaining: 1m 37s
# 437:	learn: 0.2374666	total: 1m 15s	remaining: 1m 36s
# 438:	learn: 0.2374435	total: 1m 15s	remaining: 1m 36s
# 439:	learn: 0.2374177	total: 1m 15s	remaining: 1m 36s
# 440:	learn: 0.2373939	total: 1m 16s	remaining: 1m 36s
# 441:	learn: 0.2373748	total: 1m 16s	remaining: 1m 36s
# 442:	learn: 0.2373411	total: 1m 16s	remaining: 1m 36s
# 443:	learn: 0.2373174	total: 1m 16s	remaining: 1m 35s
# 444:	learn: 0.2372887	total: 1m 16s	remaining: 1m 35s
# 445:	learn: 0.2372630	total: 1m 16s	remaining: 1m 35s
# 446:	learn: 0.2372443	total: 1m 16s	remaining: 1m 35s
# 447:	learn: 0.2372208	total: 1m 17s	remaining: 1m 35s
# 448:	learn: 0.2371959	total: 1m 17s	remaining: 1m 34s
# 449:	learn: 0.2371755	total: 1m 17s	remaining: 1m 34s
# 450:	learn: 0.2371522	total: 1m 17s	remaining: 1m 34s
# 451:	learn: 0.2371315	total: 1m 17s	remaining: 1m 34s
# 452:	learn: 0.2370997	total: 1m 17s	remaining: 1m 34s
# 453:	learn: 0.2370775	total: 1m 18s	remaining: 1m 33s
# 454:	learn: 0.2370531	total: 1m 18s	remaining: 1m 33s
# 455:	learn: 0.2370262	total: 1m 18s	remaining: 1m 33s
# 456:	learn: 0.2369989	total: 1m 18s	remaining: 1m 33s
# 457:	learn: 0.2369724	total: 1m 18s	remaining: 1m 33s
# 458:	learn: 0.2369447	total: 1m 18s	remaining: 1m 32s
# 459:	learn: 0.2369121	total: 1m 19s	remaining: 1m 32s
# 460:	learn: 0.2368935	total: 1m 19s	remaining: 1m 32s
# 461:	learn: 0.2368728	total: 1m 19s	remaining: 1m 32s
# 462:	learn: 0.2368460	total: 1m 19s	remaining: 1m 32s
# 463:	learn: 0.2368194	total: 1m 19s	remaining: 1m 31s
# 464:	learn: 0.2367899	total: 1m 19s	remaining: 1m 31s
# 465:	learn: 0.2367683	total: 1m 19s	remaining: 1m 31s
# 466:	learn: 0.2367510	total: 1m 20s	remaining: 1m 31s
# 467:	learn: 0.2367265	total: 1m 20s	remaining: 1m 31s
# 468:	learn: 0.2367098	total: 1m 20s	remaining: 1m 31s
# 469:	learn: 0.2366726	total: 1m 20s	remaining: 1m 30s
# 470:	learn: 0.2366470	total: 1m 20s	remaining: 1m 30s
# 471:	learn: 0.2366240	total: 1m 20s	remaining: 1m 30s
# 472:	learn: 0.2365969	total: 1m 21s	remaining: 1m 30s
# 473:	learn: 0.2365733	total: 1m 21s	remaining: 1m 30s
# 474:	learn: 0.2365586	total: 1m 21s	remaining: 1m 29s
# 475:	learn: 0.2365256	total: 1m 21s	remaining: 1m 29s
# 476:	learn: 0.2364983	total: 1m 21s	remaining: 1m 29s
# 477:	learn: 0.2364741	total: 1m 21s	remaining: 1m 29s
# 478:	learn: 0.2364539	total: 1m 21s	remaining: 1m 29s
# 479:	learn: 0.2364219	total: 1m 22s	remaining: 1m 28s
# 480:	learn: 0.2364063	total: 1m 22s	remaining: 1m 28s
# 481:	learn: 0.2363789	total: 1m 22s	remaining: 1m 28s
# 482:	learn: 0.2363587	total: 1m 22s	remaining: 1m 28s
# 483:	learn: 0.2363380	total: 1m 22s	remaining: 1m 28s
# 484:	learn: 0.2363113	total: 1m 22s	remaining: 1m 28s
# 485:	learn: 0.2362770	total: 1m 23s	remaining: 1m 27s
# 486:	learn: 0.2362594	total: 1m 23s	remaining: 1m 27s
# 487:	learn: 0.2362322	total: 1m 23s	remaining: 1m 27s
# 488:	learn: 0.2362093	total: 1m 23s	remaining: 1m 27s
# 489:	learn: 0.2361747	total: 1m 23s	remaining: 1m 27s
# 490:	learn: 0.2361433	total: 1m 23s	remaining: 1m 26s
# 491:	learn: 0.2361208	total: 1m 24s	remaining: 1m 26s
# 492:	learn: 0.2361006	total: 1m 24s	remaining: 1m 26s
# 493:	learn: 0.2360797	total: 1m 24s	remaining: 1m 26s
# 494:	learn: 0.2360663	total: 1m 25s	remaining: 1m 26s
# 495:	learn: 0.2360474	total: 1m 25s	remaining: 1m 26s
# 496:	learn: 0.2360322	total: 1m 25s	remaining: 1m 26s
# 497:	learn: 0.2360001	total: 1m 25s	remaining: 1m 26s
# 498:	learn: 0.2359740	total: 1m 26s	remaining: 1m 26s
# 499:	learn: 0.2359520	total: 1m 26s	remaining: 1m 26s
# 500:	learn: 0.2359299	total: 1m 26s	remaining: 1m 26s
# 501:	learn: 0.2359043	total: 1m 26s	remaining: 1m 26s
# 502:	learn: 0.2358870	total: 1m 27s	remaining: 1m 26s
# 503:	learn: 0.2358641	total: 1m 27s	remaining: 1m 25s
# 504:	learn: 0.2358489	total: 1m 27s	remaining: 1m 25s
# 505:	learn: 0.2358321	total: 1m 27s	remaining: 1m 25s
# 506:	learn: 0.2357934	total: 1m 27s	remaining: 1m 25s
# 507:	learn: 0.2357718	total: 1m 27s	remaining: 1m 25s
# 508:	learn: 0.2357437	total: 1m 27s	remaining: 1m 24s
# 509:	learn: 0.2357291	total: 1m 28s	remaining: 1m 24s
# 510:	learn: 0.2357130	total: 1m 28s	remaining: 1m 24s
# 511:	learn: 0.2356854	total: 1m 28s	remaining: 1m 24s
# 512:	learn: 0.2356634	total: 1m 28s	remaining: 1m 24s
# 513:	learn: 0.2356380	total: 1m 28s	remaining: 1m 23s
# 514:	learn: 0.2356133	total: 1m 28s	remaining: 1m 23s
# 515:	learn: 0.2355857	total: 1m 29s	remaining: 1m 23s
# 516:	learn: 0.2355557	total: 1m 29s	remaining: 1m 23s
# 517:	learn: 0.2355229	total: 1m 29s	remaining: 1m 23s
# 518:	learn: 0.2354862	total: 1m 29s	remaining: 1m 23s
# 519:	learn: 0.2354699	total: 1m 29s	remaining: 1m 22s
# 520:	learn: 0.2354544	total: 1m 29s	remaining: 1m 22s
# 521:	learn: 0.2354354	total: 1m 29s	remaining: 1m 22s
# 522:	learn: 0.2354109	total: 1m 30s	remaining: 1m 22s
# 523:	learn: 0.2353862	total: 1m 30s	remaining: 1m 22s
# 524:	learn: 0.2353633	total: 1m 30s	remaining: 1m 21s
# 525:	learn: 0.2353404	total: 1m 30s	remaining: 1m 21s
# 526:	learn: 0.2353172	total: 1m 30s	remaining: 1m 21s
# 527:	learn: 0.2353043	total: 1m 30s	remaining: 1m 21s
# 528:	learn: 0.2352842	total: 1m 31s	remaining: 1m 21s
# 529:	learn: 0.2352594	total: 1m 31s	remaining: 1m 20s
# 530:	learn: 0.2352348	total: 1m 31s	remaining: 1m 20s
# 531:	learn: 0.2352104	total: 1m 31s	remaining: 1m 20s
# 532:	learn: 0.2351851	total: 1m 31s	remaining: 1m 20s
# 533:	learn: 0.2351625	total: 1m 31s	remaining: 1m 20s
# 534:	learn: 0.2351444	total: 1m 31s	remaining: 1m 19s
# 535:	learn: 0.2351209	total: 1m 32s	remaining: 1m 19s
# 536:	learn: 0.2350881	total: 1m 32s	remaining: 1m 19s
# 537:	learn: 0.2350696	total: 1m 32s	remaining: 1m 19s
# 538:	learn: 0.2350478	total: 1m 32s	remaining: 1m 19s
# 539:	learn: 0.2350305	total: 1m 32s	remaining: 1m 19s
# 540:	learn: 0.2350080	total: 1m 32s	remaining: 1m 18s
# 541:	learn: 0.2349879	total: 1m 33s	remaining: 1m 18s
# 542:	learn: 0.2349717	total: 1m 33s	remaining: 1m 18s
# 543:	learn: 0.2349566	total: 1m 33s	remaining: 1m 18s
# 544:	learn: 0.2349339	total: 1m 33s	remaining: 1m 18s
# 545:	learn: 0.2349159	total: 1m 33s	remaining: 1m 17s
# 546:	learn: 0.2348831	total: 1m 33s	remaining: 1m 17s
# 547:	learn: 0.2348607	total: 1m 33s	remaining: 1m 17s
# 548:	learn: 0.2348384	total: 1m 34s	remaining: 1m 17s
# 549:	learn: 0.2348175	total: 1m 34s	remaining: 1m 17s
# 550:	learn: 0.2347961	total: 1m 34s	remaining: 1m 16s
# 551:	learn: 0.2347753	total: 1m 34s	remaining: 1m 16s
# 552:	learn: 0.2347494	total: 1m 34s	remaining: 1m 16s
# 553:	learn: 0.2347325	total: 1m 34s	remaining: 1m 16s
# 554:	learn: 0.2347170	total: 1m 34s	remaining: 1m 16s
# 555:	learn: 0.2346976	total: 1m 35s	remaining: 1m 15s
# 556:	learn: 0.2346808	total: 1m 35s	remaining: 1m 15s
# 557:	learn: 0.2346544	total: 1m 35s	remaining: 1m 15s
# 558:	learn: 0.2346277	total: 1m 35s	remaining: 1m 15s
# 559:	learn: 0.2346001	total: 1m 35s	remaining: 1m 15s
# 560:	learn: 0.2345795	total: 1m 35s	remaining: 1m 15s
# 561:	learn: 0.2345641	total: 1m 36s	remaining: 1m 14s
# 562:	learn: 0.2345293	total: 1m 36s	remaining: 1m 14s
# 563:	learn: 0.2345058	total: 1m 36s	remaining: 1m 14s
# 564:	learn: 0.2344877	total: 1m 36s	remaining: 1m 14s
# 565:	learn: 0.2344616	total: 1m 36s	remaining: 1m 14s
# 566:	learn: 0.2344394	total: 1m 37s	remaining: 1m 14s
# 567:	learn: 0.2344202	total: 1m 37s	remaining: 1m 14s
# 568:	learn: 0.2343928	total: 1m 37s	remaining: 1m 13s
# 569:	learn: 0.2343740	total: 1m 37s	remaining: 1m 13s
# 570:	learn: 0.2343532	total: 1m 38s	remaining: 1m 13s
# 571:	learn: 0.2343365	total: 1m 38s	remaining: 1m 13s
# 572:	learn: 0.2343147	total: 1m 38s	remaining: 1m 13s
# 573:	learn: 0.2342974	total: 1m 39s	remaining: 1m 13s
# 574:	learn: 0.2342702	total: 1m 39s	remaining: 1m 13s
# 575:	learn: 0.2342451	total: 1m 39s	remaining: 1m 13s
# 576:	learn: 0.2342261	total: 1m 39s	remaining: 1m 13s
# 577:	learn: 0.2342105	total: 1m 39s	remaining: 1m 12s
# 578:	learn: 0.2341841	total: 1m 40s	remaining: 1m 12s
# 579:	learn: 0.2341710	total: 1m 40s	remaining: 1m 12s
# 580:	learn: 0.2341510	total: 1m 40s	remaining: 1m 12s
# 581:	learn: 0.2341351	total: 1m 40s	remaining: 1m 12s
# 582:	learn: 0.2341170	total: 1m 40s	remaining: 1m 12s
# 583:	learn: 0.2340933	total: 1m 40s	remaining: 1m 11s
# 584:	learn: 0.2340757	total: 1m 40s	remaining: 1m 11s
# 585:	learn: 0.2340577	total: 1m 41s	remaining: 1m 11s
# 586:	learn: 0.2340262	total: 1m 41s	remaining: 1m 11s
# 587:	learn: 0.2340097	total: 1m 41s	remaining: 1m 11s
# 588:	learn: 0.2339813	total: 1m 41s	remaining: 1m 10s
# 589:	learn: 0.2339591	total: 1m 41s	remaining: 1m 10s
# 590:	learn: 0.2339376	total: 1m 41s	remaining: 1m 10s
# 591:	learn: 0.2339113	total: 1m 42s	remaining: 1m 10s
# 592:	learn: 0.2338873	total: 1m 42s	remaining: 1m 10s
# 593:	learn: 0.2338727	total: 1m 42s	remaining: 1m 9s
# 594:	learn: 0.2338544	total: 1m 42s	remaining: 1m 9s
# 595:	learn: 0.2338350	total: 1m 42s	remaining: 1m 9s
# 596:	learn: 0.2338075	total: 1m 42s	remaining: 1m 9s
# 597:	learn: 0.2337773	total: 1m 42s	remaining: 1m 9s
# 598:	learn: 0.2337487	total: 1m 43s	remaining: 1m 9s
# 599:	learn: 0.2337228	total: 1m 43s	remaining: 1m 8s
# 600:	learn: 0.2337032	total: 1m 43s	remaining: 1m 8s
# 601:	learn: 0.2336859	total: 1m 43s	remaining: 1m 8s
# 602:	learn: 0.2336657	total: 1m 43s	remaining: 1m 8s
# 603:	learn: 0.2336444	total: 1m 43s	remaining: 1m 8s
# 604:	learn: 0.2336147	total: 1m 44s	remaining: 1m 7s
# 605:	learn: 0.2335912	total: 1m 44s	remaining: 1m 7s
# 606:	learn: 0.2335625	total: 1m 44s	remaining: 1m 7s
# 607:	learn: 0.2335399	total: 1m 44s	remaining: 1m 7s
# 608:	learn: 0.2335178	total: 1m 44s	remaining: 1m 7s
# 609:	learn: 0.2335036	total: 1m 44s	remaining: 1m 7s
# 610:	learn: 0.2334858	total: 1m 44s	remaining: 1m 6s
# 611:	learn: 0.2334649	total: 1m 45s	remaining: 1m 6s
# 612:	learn: 0.2334429	total: 1m 45s	remaining: 1m 6s
# 613:	learn: 0.2334203	total: 1m 45s	remaining: 1m 6s
# 614:	learn: 0.2333944	total: 1m 45s	remaining: 1m 6s
# 615:	learn: 0.2333762	total: 1m 45s	remaining: 1m 5s
# 616:	learn: 0.2333525	total: 1m 45s	remaining: 1m 5s
# 617:	learn: 0.2333356	total: 1m 46s	remaining: 1m 5s
# 618:	learn: 0.2333211	total: 1m 46s	remaining: 1m 5s
# 619:	learn: 0.2333029	total: 1m 46s	remaining: 1m 5s
# 620:	learn: 0.2332778	total: 1m 46s	remaining: 1m 4s
# 621:	learn: 0.2332676	total: 1m 46s	remaining: 1m 4s
# 622:	learn: 0.2332420	total: 1m 46s	remaining: 1m 4s
# 623:	learn: 0.2332257	total: 1m 46s	remaining: 1m 4s
# 624:	learn: 0.2332040	total: 1m 47s	remaining: 1m 4s
# 625:	learn: 0.2331849	total: 1m 47s	remaining: 1m 4s
# 626:	learn: 0.2331614	total: 1m 47s	remaining: 1m 3s
# 627:	learn: 0.2331375	total: 1m 47s	remaining: 1m 3s
# 628:	learn: 0.2331174	total: 1m 47s	remaining: 1m 3s
# 629:	learn: 0.2330939	total: 1m 47s	remaining: 1m 3s
# 630:	learn: 0.2330669	total: 1m 48s	remaining: 1m 3s
# 631:	learn: 0.2330453	total: 1m 48s	remaining: 1m 2s
# 632:	learn: 0.2330367	total: 1m 48s	remaining: 1m 2s
# 633:	learn: 0.2330157	total: 1m 48s	remaining: 1m 2s
# 634:	learn: 0.2329876	total: 1m 48s	remaining: 1m 2s
# 635:	learn: 0.2329594	total: 1m 48s	remaining: 1m 2s
# 636:	learn: 0.2329389	total: 1m 48s	remaining: 1m 2s
# 637:	learn: 0.2329191	total: 1m 49s	remaining: 1m 1s
# 638:	learn: 0.2328995	total: 1m 49s	remaining: 1m 1s
# 639:	learn: 0.2328854	total: 1m 49s	remaining: 1m 1s
# 640:	learn: 0.2328706	total: 1m 49s	remaining: 1m 1s
# 641:	learn: 0.2328488	total: 1m 49s	remaining: 1m 1s
# 642:	learn: 0.2328229	total: 1m 50s	remaining: 1m 1s
# 643:	learn: 0.2328038	total: 1m 50s	remaining: 1m 1s
# 644:	learn: 0.2327861	total: 1m 50s	remaining: 1m
# 645:	learn: 0.2327674	total: 1m 51s	remaining: 1m
# 646:	learn: 0.2327421	total: 1m 51s	remaining: 1m
# 647:	learn: 0.2327242	total: 1m 51s	remaining: 1m
# 648:	learn: 0.2327137	total: 1m 51s	remaining: 1m
# 649:	learn: 0.2326857	total: 1m 52s	remaining: 1m
# 650:	learn: 0.2326534	total: 1m 52s	remaining: 1m
# 651:	learn: 0.2326417	total: 1m 52s	remaining: 1m
# 652:	learn: 0.2326252	total: 1m 52s	remaining: 60s
# 653:	learn: 0.2326015	total: 1m 53s	remaining: 59.8s
# 654:	learn: 0.2325830	total: 1m 53s	remaining: 59.6s
# 655:	learn: 0.2325529	total: 1m 53s	remaining: 59.4s
# 656:	learn: 0.2325269	total: 1m 53s	remaining: 59.2s
# 657:	learn: 0.2325053	total: 1m 53s	remaining: 59.1s
# 658:	learn: 0.2324792	total: 1m 53s	remaining: 58.9s
# 659:	learn: 0.2324487	total: 1m 53s	remaining: 58.7s
# 660:	learn: 0.2324298	total: 1m 54s	remaining: 58.5s
# 661:	learn: 0.2324193	total: 1m 54s	remaining: 58.3s
# 662:	learn: 0.2323967	total: 1m 54s	remaining: 58.1s
# 663:	learn: 0.2323843	total: 1m 54s	remaining: 58s
# 664:	learn: 0.2323705	total: 1m 54s	remaining: 57.8s
# 665:	learn: 0.2323407	total: 1m 54s	remaining: 57.6s
# 666:	learn: 0.2323205	total: 1m 54s	remaining: 57.4s
# 667:	learn: 0.2323041	total: 1m 55s	remaining: 57.2s
# 668:	learn: 0.2322903	total: 1m 55s	remaining: 57s
# 669:	learn: 0.2322691	total: 1m 55s	remaining: 56.9s
# 670:	learn: 0.2322358	total: 1m 55s	remaining: 56.7s
# 671:	learn: 0.2322162	total: 1m 55s	remaining: 56.5s
# 672:	learn: 0.2322012	total: 1m 55s	remaining: 56.3s
# 673:	learn: 0.2321795	total: 1m 56s	remaining: 56.1s
# 674:	learn: 0.2321598	total: 1m 56s	remaining: 55.9s
# 675:	learn: 0.2321361	total: 1m 56s	remaining: 55.8s
# 676:	learn: 0.2321203	total: 1m 56s	remaining: 55.6s
# 677:	learn: 0.2320997	total: 1m 56s	remaining: 55.4s
# 678:	learn: 0.2320776	total: 1m 56s	remaining: 55.2s
# 679:	learn: 0.2320597	total: 1m 56s	remaining: 55s
# 680:	learn: 0.2320381	total: 1m 57s	remaining: 54.8s
# 681:	learn: 0.2320097	total: 1m 57s	remaining: 54.7s
# 682:	learn: 0.2319694	total: 1m 57s	remaining: 54.5s
# 683:	learn: 0.2319530	total: 1m 57s	remaining: 54.3s
# 684:	learn: 0.2319215	total: 1m 57s	remaining: 54.1s
# 685:	learn: 0.2319089	total: 1m 57s	remaining: 54s
# 686:	learn: 0.2318867	total: 1m 58s	remaining: 53.8s
# 687:	learn: 0.2318630	total: 1m 58s	remaining: 53.6s
# 688:	learn: 0.2318317	total: 1m 58s	remaining: 53.4s
# 689:	learn: 0.2318111	total: 1m 58s	remaining: 53.2s
# 690:	learn: 0.2317827	total: 1m 58s	remaining: 53.1s
# 691:	learn: 0.2317617	total: 1m 58s	remaining: 52.9s
# 692:	learn: 0.2317370	total: 1m 58s	remaining: 52.7s
# 693:	learn: 0.2317276	total: 1m 59s	remaining: 52.5s
# 694:	learn: 0.2317086	total: 1m 59s	remaining: 52.3s
# 695:	learn: 0.2316846	total: 1m 59s	remaining: 52.1s
# 696:	learn: 0.2316695	total: 1m 59s	remaining: 52s
# 697:	learn: 0.2316474	total: 1m 59s	remaining: 51.8s
# 698:	learn: 0.2316251	total: 1m 59s	remaining: 51.6s
# 699:	learn: 0.2315977	total: 2m	remaining: 51.4s
# 700:	learn: 0.2315592	total: 2m	remaining: 51.3s
# 701:	learn: 0.2315373	total: 2m	remaining: 51.1s
# 702:	learn: 0.2315147	total: 2m	remaining: 50.9s
# 703:	learn: 0.2314885	total: 2m	remaining: 50.7s
# 704:	learn: 0.2314659	total: 2m	remaining: 50.6s
# 705:	learn: 0.2314379	total: 2m	remaining: 50.4s
# 706:	learn: 0.2314150	total: 2m 1s	remaining: 50.2s
# 707:	learn: 0.2313957	total: 2m 1s	remaining: 50s
# 708:	learn: 0.2313724	total: 2m 1s	remaining: 49.8s
# 709:	learn: 0.2313502	total: 2m 1s	remaining: 49.7s
# 710:	learn: 0.2313277	total: 2m 1s	remaining: 49.5s
# 711:	learn: 0.2313122	total: 2m 1s	remaining: 49.3s
# 712:	learn: 0.2312939	total: 2m 2s	remaining: 49.1s
# 713:	learn: 0.2312756	total: 2m 2s	remaining: 48.9s
# 714:	learn: 0.2312562	total: 2m 2s	remaining: 48.8s
# 715:	learn: 0.2312326	total: 2m 2s	remaining: 48.6s
# 716:	learn: 0.2312090	total: 2m 2s	remaining: 48.4s
# 717:	learn: 0.2311847	total: 2m 2s	remaining: 48.3s
# 718:	learn: 0.2311597	total: 2m 3s	remaining: 48.2s
# 719:	learn: 0.2311379	total: 2m 3s	remaining: 48.1s
# 720:	learn: 0.2311239	total: 2m 3s	remaining: 48s
# 721:	learn: 0.2311065	total: 2m 4s	remaining: 47.8s
# 722:	learn: 0.2310882	total: 2m 4s	remaining: 47.7s
# 723:	learn: 0.2310671	total: 2m 4s	remaining: 47.6s
# 724:	learn: 0.2310376	total: 2m 5s	remaining: 47.5s
# 725:	learn: 0.2310087	total: 2m 5s	remaining: 47.3s
# 726:	learn: 0.2309852	total: 2m 5s	remaining: 47.2s
# 727:	learn: 0.2309664	total: 2m 5s	remaining: 47s
# 728:	learn: 0.2309427	total: 2m 5s	remaining: 46.8s
# 729:	learn: 0.2309201	total: 2m 6s	remaining: 46.6s
# 730:	learn: 0.2308969	total: 2m 6s	remaining: 46.5s
# 731:	learn: 0.2308744	total: 2m 6s	remaining: 46.3s
# 732:	learn: 0.2308520	total: 2m 6s	remaining: 46.1s
# 733:	learn: 0.2308353	total: 2m 6s	remaining: 45.9s
# 734:	learn: 0.2308112	total: 2m 6s	remaining: 45.8s
# 735:	learn: 0.2307889	total: 2m 7s	remaining: 45.6s
# 736:	learn: 0.2307675	total: 2m 7s	remaining: 45.4s
# 737:	learn: 0.2307472	total: 2m 7s	remaining: 45.2s
# 738:	learn: 0.2307188	total: 2m 7s	remaining: 45s
# 739:	learn: 0.2307065	total: 2m 7s	remaining: 44.8s
# 740:	learn: 0.2306897	total: 2m 7s	remaining: 44.7s
# 741:	learn: 0.2306659	total: 2m 7s	remaining: 44.5s
# 742:	learn: 0.2306475	total: 2m 8s	remaining: 44.3s
# 743:	learn: 0.2306354	total: 2m 8s	remaining: 44.1s
# 744:	learn: 0.2306171	total: 2m 8s	remaining: 44s
# 745:	learn: 0.2305918	total: 2m 8s	remaining: 43.8s
# 746:	learn: 0.2305676	total: 2m 8s	remaining: 43.6s
# 747:	learn: 0.2305439	total: 2m 8s	remaining: 43.4s
# 748:	learn: 0.2305274	total: 2m 9s	remaining: 43.2s
# 749:	learn: 0.2305096	total: 2m 9s	remaining: 43.1s
# 750:	learn: 0.2304868	total: 2m 9s	remaining: 42.9s
# 751:	learn: 0.2304663	total: 2m 9s	remaining: 42.7s
# 752:	learn: 0.2304467	total: 2m 9s	remaining: 42.5s
# 753:	learn: 0.2304254	total: 2m 9s	remaining: 42.4s
# 754:	learn: 0.2304002	total: 2m 9s	remaining: 42.2s
# 755:	learn: 0.2303772	total: 2m 10s	remaining: 42s
# 756:	learn: 0.2303543	total: 2m 10s	remaining: 41.8s
# 757:	learn: 0.2303263	total: 2m 10s	remaining: 41.6s
# 758:	learn: 0.2303106	total: 2m 10s	remaining: 41.5s
# 759:	learn: 0.2302966	total: 2m 10s	remaining: 41.3s
# 760:	learn: 0.2302781	total: 2m 10s	remaining: 41.1s
# 761:	learn: 0.2302524	total: 2m 11s	remaining: 40.9s
# 762:	learn: 0.2302276	total: 2m 11s	remaining: 40.7s
# 763:	learn: 0.2302060	total: 2m 11s	remaining: 40.6s
# 764:	learn: 0.2301871	total: 2m 11s	remaining: 40.4s
# 765:	learn: 0.2301656	total: 2m 11s	remaining: 40.2s
# 766:	learn: 0.2301421	total: 2m 11s	remaining: 40s
# 767:	learn: 0.2301194	total: 2m 11s	remaining: 39.8s
# 768:	learn: 0.2301029	total: 2m 12s	remaining: 39.7s
# 769:	learn: 0.2300806	total: 2m 12s	remaining: 39.5s
# 770:	learn: 0.2300582	total: 2m 12s	remaining: 39.3s
# 771:	learn: 0.2300318	total: 2m 12s	remaining: 39.1s
# 772:	learn: 0.2300040	total: 2m 12s	remaining: 39s
# 773:	learn: 0.2299819	total: 2m 12s	remaining: 38.8s
# 774:	learn: 0.2299706	total: 2m 12s	remaining: 38.6s
# 775:	learn: 0.2299524	total: 2m 13s	remaining: 38.4s
# 776:	learn: 0.2299291	total: 2m 13s	remaining: 38.3s
# 777:	learn: 0.2299201	total: 2m 13s	remaining: 38.1s
# 778:	learn: 0.2299068	total: 2m 13s	remaining: 37.9s
# 779:	learn: 0.2298916	total: 2m 13s	remaining: 37.7s
# 780:	learn: 0.2298751	total: 2m 13s	remaining: 37.5s
# 781:	learn: 0.2298615	total: 2m 14s	remaining: 37.4s
# 782:	learn: 0.2298384	total: 2m 14s	remaining: 37.2s
# 783:	learn: 0.2298244	total: 2m 14s	remaining: 37s
# 784:	learn: 0.2298066	total: 2m 14s	remaining: 36.8s
# 785:	learn: 0.2297869	total: 2m 14s	remaining: 36.7s
# 786:	learn: 0.2297696	total: 2m 14s	remaining: 36.5s
# 787:	learn: 0.2297504	total: 2m 14s	remaining: 36.3s
# 788:	learn: 0.2297361	total: 2m 15s	remaining: 36.1s
# 789:	learn: 0.2297193	total: 2m 15s	remaining: 35.9s
# 790:	learn: 0.2296955	total: 2m 15s	remaining: 35.8s
# 791:	learn: 0.2296730	total: 2m 15s	remaining: 35.6s
# 792:	learn: 0.2296526	total: 2m 15s	remaining: 35.4s
# 793:	learn: 0.2296243	total: 2m 16s	remaining: 35.3s
# 794:	learn: 0.2296039	total: 2m 16s	remaining: 35.2s
# 795:	learn: 0.2295822	total: 2m 16s	remaining: 35s
# 796:	learn: 0.2295666	total: 2m 16s	remaining: 34.9s
# 797:	learn: 0.2295436	total: 2m 17s	remaining: 34.7s
# 798:	learn: 0.2295336	total: 2m 17s	remaining: 34.6s
# 799:	learn: 0.2295141	total: 2m 17s	remaining: 34.5s
# 800:	learn: 0.2294946	total: 2m 18s	remaining: 34.3s
# 801:	learn: 0.2294746	total: 2m 18s	remaining: 34.2s
# 802:	learn: 0.2294469	total: 2m 18s	remaining: 34s
# 803:	learn: 0.2294268	total: 2m 18s	remaining: 33.8s
# 804:	learn: 0.2294088	total: 2m 19s	remaining: 33.7s
# 805:	learn: 0.2293865	total: 2m 19s	remaining: 33.5s
# 806:	learn: 0.2293669	total: 2m 19s	remaining: 33.3s
# 807:	learn: 0.2293474	total: 2m 19s	remaining: 33.1s
# 808:	learn: 0.2293290	total: 2m 19s	remaining: 33s
# 809:	learn: 0.2293073	total: 2m 19s	remaining: 32.8s
# 810:	learn: 0.2292933	total: 2m 19s	remaining: 32.6s
# 811:	learn: 0.2292700	total: 2m 20s	remaining: 32.4s
# 812:	learn: 0.2292485	total: 2m 20s	remaining: 32.2s
# 813:	learn: 0.2292285	total: 2m 20s	remaining: 32.1s
# 814:	learn: 0.2292170	total: 2m 20s	remaining: 31.9s
# 815:	learn: 0.2291946	total: 2m 20s	remaining: 31.7s
# 816:	learn: 0.2291722	total: 2m 20s	remaining: 31.5s
# 817:	learn: 0.2291526	total: 2m 20s	remaining: 31.4s
# 818:	learn: 0.2291342	total: 2m 21s	remaining: 31.2s
# 819:	learn: 0.2291220	total: 2m 21s	remaining: 31s
# 820:	learn: 0.2291030	total: 2m 21s	remaining: 30.8s
# 821:	learn: 0.2290861	total: 2m 21s	remaining: 30.7s
# 822:	learn: 0.2290718	total: 2m 21s	remaining: 30.5s
# 823:	learn: 0.2290601	total: 2m 21s	remaining: 30.3s
# 824:	learn: 0.2290338	total: 2m 22s	remaining: 30.1s
# 825:	learn: 0.2290119	total: 2m 22s	remaining: 30s
# 826:	learn: 0.2289813	total: 2m 22s	remaining: 29.8s
# 827:	learn: 0.2289648	total: 2m 22s	remaining: 29.6s
# 828:	learn: 0.2289485	total: 2m 22s	remaining: 29.4s
# 829:	learn: 0.2289334	total: 2m 22s	remaining: 29.3s
# 830:	learn: 0.2289157	total: 2m 22s	remaining: 29.1s
# 831:	learn: 0.2288874	total: 2m 23s	remaining: 28.9s
# 832:	learn: 0.2288634	total: 2m 23s	remaining: 28.7s
# 833:	learn: 0.2288478	total: 2m 23s	remaining: 28.6s
# 834:	learn: 0.2288289	total: 2m 23s	remaining: 28.4s
# 835:	learn: 0.2288077	total: 2m 23s	remaining: 28.2s
# 836:	learn: 0.2287861	total: 2m 23s	remaining: 28s
# 837:	learn: 0.2287687	total: 2m 24s	remaining: 27.9s
# 838:	learn: 0.2287470	total: 2m 24s	remaining: 27.7s
# 839:	learn: 0.2287252	total: 2m 24s	remaining: 27.5s
# 840:	learn: 0.2287073	total: 2m 24s	remaining: 27.3s
# 841:	learn: 0.2286789	total: 2m 24s	remaining: 27.1s
# 842:	learn: 0.2286651	total: 2m 24s	remaining: 27s
# 843:	learn: 0.2286365	total: 2m 24s	remaining: 26.8s
# 844:	learn: 0.2286153	total: 2m 25s	remaining: 26.6s
# 845:	learn: 0.2285977	total: 2m 25s	remaining: 26.4s
# 846:	learn: 0.2285774	total: 2m 25s	remaining: 26.3s
# 847:	learn: 0.2285668	total: 2m 25s	remaining: 26.1s
# 848:	learn: 0.2285517	total: 2m 25s	remaining: 25.9s
# 849:	learn: 0.2285336	total: 2m 25s	remaining: 25.7s
# 850:	learn: 0.2285132	total: 2m 26s	remaining: 25.6s
# 851:	learn: 0.2284950	total: 2m 26s	remaining: 25.4s
# 852:	learn: 0.2284671	total: 2m 26s	remaining: 25.2s
# 853:	learn: 0.2284422	total: 2m 26s	remaining: 25s
# 854:	learn: 0.2284279	total: 2m 26s	remaining: 24.9s
# 855:	learn: 0.2284109	total: 2m 26s	remaining: 24.7s
# 856:	learn: 0.2283973	total: 2m 26s	remaining: 24.5s
# 857:	learn: 0.2283714	total: 2m 27s	remaining: 24.4s
# 858:	learn: 0.2283473	total: 2m 27s	remaining: 24.2s
# 859:	learn: 0.2283283	total: 2m 27s	remaining: 24s
# 860:	learn: 0.2283219	total: 2m 27s	remaining: 23.8s
# 861:	learn: 0.2283012	total: 2m 27s	remaining: 23.7s
# 862:	learn: 0.2282849	total: 2m 27s	remaining: 23.5s
# 863:	learn: 0.2282650	total: 2m 28s	remaining: 23.3s
# 864:	learn: 0.2282470	total: 2m 28s	remaining: 23.1s
# 865:	learn: 0.2282305	total: 2m 28s	remaining: 23s
# 866:	learn: 0.2282100	total: 2m 28s	remaining: 22.8s
# 867:	learn: 0.2281967	total: 2m 28s	remaining: 22.6s
# 868:	learn: 0.2281731	total: 2m 29s	remaining: 22.5s
# 869:	learn: 0.2281594	total: 2m 29s	remaining: 22.3s
# 870:	learn: 0.2281326	total: 2m 29s	remaining: 22.2s
# 871:	learn: 0.2281075	total: 2m 29s	remaining: 22s
# 872:	learn: 0.2280848	total: 2m 30s	remaining: 21.9s
# 873:	learn: 0.2280686	total: 2m 30s	remaining: 21.8s
# 874:	learn: 0.2280457	total: 2m 31s	remaining: 21.6s
# 875:	learn: 0.2280277	total: 2m 32s	remaining: 21.5s
# 876:	learn: 0.2280095	total: 2m 32s	remaining: 21.4s
# 877:	learn: 0.2279965	total: 2m 32s	remaining: 21.2s
# 878:	learn: 0.2279857	total: 2m 33s	remaining: 21.1s
# 879:	learn: 0.2279618	total: 2m 33s	remaining: 20.9s
# 880:	learn: 0.2279450	total: 2m 33s	remaining: 20.8s
# 881:	learn: 0.2279316	total: 2m 33s	remaining: 20.6s
# 882:	learn: 0.2279166	total: 2m 34s	remaining: 20.4s
# 883:	learn: 0.2278966	total: 2m 34s	remaining: 20.2s
# 884:	learn: 0.2278852	total: 2m 34s	remaining: 20.1s
# 885:	learn: 0.2278657	total: 2m 34s	remaining: 19.9s
# 886:	learn: 0.2278563	total: 2m 34s	remaining: 19.7s
# 887:	learn: 0.2278373	total: 2m 34s	remaining: 19.5s
# 888:	learn: 0.2278148	total: 2m 35s	remaining: 19.4s
# 889:	learn: 0.2277957	total: 2m 35s	remaining: 19.2s
# 890:	learn: 0.2277842	total: 2m 35s	remaining: 19s
# 891:	learn: 0.2277619	total: 2m 35s	remaining: 18.8s
# 892:	learn: 0.2277459	total: 2m 35s	remaining: 18.6s
# 893:	learn: 0.2277361	total: 2m 35s	remaining: 18.5s
# 894:	learn: 0.2277144	total: 2m 35s	remaining: 18.3s
# 895:	learn: 0.2276977	total: 2m 36s	remaining: 18.1s
# 896:	learn: 0.2276794	total: 2m 36s	remaining: 17.9s
# 897:	learn: 0.2276616	total: 2m 36s	remaining: 17.8s
# 898:	learn: 0.2276425	total: 2m 36s	remaining: 17.6s
# 899:	learn: 0.2276276	total: 2m 36s	remaining: 17.4s
# 900:	learn: 0.2276035	total: 2m 36s	remaining: 17.2s
# 901:	learn: 0.2275773	total: 2m 36s	remaining: 17.1s
# 902:	learn: 0.2275506	total: 2m 37s	remaining: 16.9s
# 903:	learn: 0.2275310	total: 2m 37s	remaining: 16.7s
# 904:	learn: 0.2275124	total: 2m 37s	remaining: 16.5s
# 905:	learn: 0.2274890	total: 2m 37s	remaining: 16.4s
# 906:	learn: 0.2274688	total: 2m 37s	remaining: 16.2s
# 907:	learn: 0.2274482	total: 2m 37s	remaining: 16s
# 908:	learn: 0.2274340	total: 2m 38s	remaining: 15.8s
# 909:	learn: 0.2274209	total: 2m 38s	remaining: 15.7s
# 910:	learn: 0.2274043	total: 2m 38s	remaining: 15.5s
# 911:	learn: 0.2273892	total: 2m 38s	remaining: 15.3s
# 912:	learn: 0.2273724	total: 2m 38s	remaining: 15.1s
# 913:	learn: 0.2273462	total: 2m 38s	remaining: 15s
# 914:	learn: 0.2273369	total: 2m 39s	remaining: 14.8s
# 915:	learn: 0.2273157	total: 2m 39s	remaining: 14.6s
# 916:	learn: 0.2273041	total: 2m 39s	remaining: 14.4s
# 917:	learn: 0.2272811	total: 2m 39s	remaining: 14.2s
# 918:	learn: 0.2272580	total: 2m 39s	remaining: 14.1s
# 919:	learn: 0.2272324	total: 2m 39s	remaining: 13.9s
# 920:	learn: 0.2272172	total: 2m 39s	remaining: 13.7s
# 921:	learn: 0.2272077	total: 2m 40s	remaining: 13.5s
# 922:	learn: 0.2271901	total: 2m 40s	remaining: 13.4s
# 923:	learn: 0.2271689	total: 2m 40s	remaining: 13.2s
# 924:	learn: 0.2271593	total: 2m 40s	remaining: 13s
# 925:	learn: 0.2271393	total: 2m 40s	remaining: 12.8s
# 926:	learn: 0.2271289	total: 2m 40s	remaining: 12.7s
# 927:	learn: 0.2271069	total: 2m 41s	remaining: 12.5s
# 928:	learn: 0.2270949	total: 2m 41s	remaining: 12.3s
# 929:	learn: 0.2270702	total: 2m 41s	remaining: 12.1s
# 930:	learn: 0.2270433	total: 2m 41s	remaining: 12s
# 931:	learn: 0.2270231	total: 2m 41s	remaining: 11.8s
# 932:	learn: 0.2270001	total: 2m 41s	remaining: 11.6s
# 933:	learn: 0.2269805	total: 2m 41s	remaining: 11.4s
# 934:	learn: 0.2269612	total: 2m 42s	remaining: 11.3s
# 935:	learn: 0.2269466	total: 2m 42s	remaining: 11.1s
# 936:	learn: 0.2269347	total: 2m 42s	remaining: 10.9s
# 937:	learn: 0.2269250	total: 2m 42s	remaining: 10.7s
# 938:	learn: 0.2269100	total: 2m 42s	remaining: 10.6s
# 939:	learn: 0.2268905	total: 2m 42s	remaining: 10.4s
# 940:	learn: 0.2268765	total: 2m 43s	remaining: 10.2s
# 941:	learn: 0.2268556	total: 2m 43s	remaining: 10s
# 942:	learn: 0.2268398	total: 2m 43s	remaining: 9.88s
# 943:	learn: 0.2268275	total: 2m 43s	remaining: 9.71s
# 944:	learn: 0.2268052	total: 2m 43s	remaining: 9.54s
# 945:	learn: 0.2267848	total: 2m 44s	remaining: 9.38s
# 946:	learn: 0.2267650	total: 2m 44s	remaining: 9.21s
# 947:	learn: 0.2267460	total: 2m 44s	remaining: 9.05s
# 948:	learn: 0.2267339	total: 2m 45s	remaining: 8.88s
# 949:	learn: 0.2267137	total: 2m 45s	remaining: 8.71s
# 950:	learn: 0.2266989	total: 2m 45s	remaining: 8.54s
# 951:	learn: 0.2266854	total: 2m 46s	remaining: 8.37s
# 952:	learn: 0.2266720	total: 2m 46s	remaining: 8.21s
# 953:	learn: 0.2266519	total: 2m 46s	remaining: 8.03s
# 954:	learn: 0.2266271	total: 2m 46s	remaining: 7.86s
# 955:	learn: 0.2265986	total: 2m 46s	remaining: 7.68s
# 956:	learn: 0.2265830	total: 2m 47s	remaining: 7.5s
# 957:	learn: 0.2265654	total: 2m 47s	remaining: 7.33s
# 958:	learn: 0.2265496	total: 2m 47s	remaining: 7.15s
# 959:	learn: 0.2265220	total: 2m 47s	remaining: 6.98s
# 960:	learn: 0.2265032	total: 2m 47s	remaining: 6.8s
# 961:	learn: 0.2264883	total: 2m 47s	remaining: 6.63s
# 962:	learn: 0.2264691	total: 2m 47s	remaining: 6.45s
# 963:	learn: 0.2264458	total: 2m 48s	remaining: 6.28s
# 964:	learn: 0.2264381	total: 2m 48s	remaining: 6.1s
# 965:	learn: 0.2264235	total: 2m 48s	remaining: 5.92s
# 966:	learn: 0.2264054	total: 2m 48s	remaining: 5.75s
# 967:	learn: 0.2263822	total: 2m 48s	remaining: 5.58s
# 968:	learn: 0.2263644	total: 2m 48s	remaining: 5.4s
# 969:	learn: 0.2263485	total: 2m 48s	remaining: 5.23s
# 970:	learn: 0.2263320	total: 2m 49s	remaining: 5.05s
# 971:	learn: 0.2263161	total: 2m 49s	remaining: 4.88s
# 972:	learn: 0.2262982	total: 2m 49s	remaining: 4.7s
# 973:	learn: 0.2262865	total: 2m 49s	remaining: 4.53s
# 974:	learn: 0.2262647	total: 2m 49s	remaining: 4.35s
# 975:	learn: 0.2262484	total: 2m 49s	remaining: 4.18s
# 976:	learn: 0.2262345	total: 2m 50s	remaining: 4s
# 977:	learn: 0.2262143	total: 2m 50s	remaining: 3.83s
# 978:	learn: 0.2261928	total: 2m 50s	remaining: 3.65s
# 979:	learn: 0.2261725	total: 2m 50s	remaining: 3.48s
# 980:	learn: 0.2261526	total: 2m 50s	remaining: 3.31s
# 981:	learn: 0.2261334	total: 2m 50s	remaining: 3.13s
# 982:	learn: 0.2261205	total: 2m 50s	remaining: 2.96s
# 983:	learn: 0.2261070	total: 2m 51s	remaining: 2.78s
# 984:	learn: 0.2260822	total: 2m 51s	remaining: 2.61s
# 985:	learn: 0.2260552	total: 2m 51s	remaining: 2.43s
# 986:	learn: 0.2260402	total: 2m 51s	remaining: 2.26s
# 987:	learn: 0.2260133	total: 2m 51s	remaining: 2.09s
# 988:	learn: 0.2260001	total: 2m 51s	remaining: 1.91s
# 989:	learn: 0.2259789	total: 2m 52s	remaining: 1.74s
# 990:	learn: 0.2259556	total: 2m 52s	remaining: 1.56s
# 991:	learn: 0.2259410	total: 2m 52s	remaining: 1.39s
# 992:	learn: 0.2259159	total: 2m 52s	remaining: 1.22s
# 993:	learn: 0.2258973	total: 2m 52s	remaining: 1.04s
# 994:	learn: 0.2258744	total: 2m 52s	remaining: 869ms
# 995:	learn: 0.2258578	total: 2m 53s	remaining: 695ms
# 996:	learn: 0.2258377	total: 2m 53s	remaining: 521ms
# 997:	learn: 0.2258191	total: 2m 53s	remaining: 347ms
# 998:	learn: 0.2257978	total: 2m 53s	remaining: 174ms
# 999:	learn: 0.2257783	total: 2m 53s	remaining: 0us

# %%
y_pred = clf.predict_proba(x_test)

# %%
x_test['Not_Delayed'] =  y_pred[:,:1]
x_test['Delayed'] =  y_pred[:,1:]
x_test = x_test.reset_index()

# %%
sample_submission = sample_submission.reset_index()
sample_submission = sample_submission.drop(columns = ['index', 'Not_Delayed','Delayed'])

# %%
sample_submission = pd.merge(sample_submission, x_test[['ID', 'Not_Delayed','Delayed']], on = 'ID', how = 'outer')
sample_submission
#submission = pd.DataFrame(data=y_pred, columns=sample_submission.columns, index=sample_submission.index)
# Out:
#          index  level_0           ID  Not_Delayed   Delayed
# 0            0        0  TEST_000000     0.940239  0.059761
# 1            1        1  TEST_000001     0.899434  0.100566
# 2            2        2  TEST_000002     0.790188  0.209812
# 3            3        3  TEST_000003     0.853974  0.146026
# 4            4        4  TEST_000004     0.876437  0.123563
# ...        ...      ...          ...          ...       ...
# 999995  999995   999995  TEST_999995     0.846412  0.153588
# 999996  999996   999996  TEST_999996     0.980653  0.019347
# 999997  999997   999997  TEST_999997     0.865910  0.134090
# 999998  999998   999998  TEST_999998     0.873667  0.126333
# 999999  999999   999999  TEST_999999     0.962337  0.037663
#
# [1000000 rows x 5 columns]

# %%
sample_submission = sample_submission[['ID', 'Not_Delayed','Delayed']] 
sample_submission.set_index('ID')
sample_submission
# Out:
#                  ID  Not_Delayed   Delayed
# 0       TEST_000000     0.940239  0.059761
# 1       TEST_000001     0.899434  0.100566
# 2       TEST_000002     0.790188  0.209812
# 3       TEST_000003     0.853974  0.146026
# 4       TEST_000004     0.876437  0.123563
# ...             ...          ...       ...
# 999995  TEST_999995     0.846412  0.153588
# 999996  TEST_999996     0.980653  0.019347
# 999997  TEST_999997     0.865910  0.134090
# 999998  TEST_999998     0.873667  0.126333
# 999999  TEST_999999     0.962337  0.037663
#
# [1000000 rows x 3 columns]

# %%
sample_submission['Not_Delayed'] = sample_submission['Not_Delayed'].fillna(1)
sample_submission['Delayed'] = sample_submission['Delayed'].fillna(0)
sample_submission
# Out:
#                  ID  Not_Delayed   Delayed
# 0       TEST_000000     0.940239  0.059761
# 1       TEST_000001     0.899434  0.100566
# 2       TEST_000002     0.790188  0.209812
# 3       TEST_000003     0.853974  0.146026
# 4       TEST_000004     0.876437  0.123563
# ...             ...          ...       ...
# 999995  TEST_999995     0.846412  0.153588
# 999996  TEST_999996     0.980653  0.019347
# 999997  TEST_999997     0.865910  0.134090
# 999998  TEST_999998     0.873667  0.126333
# 999999  TEST_999999     0.962337  0.037663
#
# [1000000 rows x 3 columns]

# %%
sample_submission.to_csv(os.path.join(file_dir,'submit_cat.csv'), index=False,encoding="utf-8-sig")
