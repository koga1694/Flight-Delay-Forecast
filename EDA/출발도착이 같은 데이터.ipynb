# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',None)

data = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sub = pd.read_csv('sample_submission.csv')

# %% [markdown]
# # 출발-도착 지역이 같은 데이터

# %% [markdown]
# 확인해보니 그 지역 내 다른 공항으로 이동한 경우같음. 경유는 아마 없을듯? (Diverted <- 경유 여부임 Train, Test 모두 0)
# 그 지역과 가까운 지역의 공항도 포함하는 경우가 있음.(특히 특이한 지역 (북마리아나, 알래스카 같은 지역) )
# 모든 데이터는 편도 기준으로 기록되는 것 같음.

# %%
check = data[(data['Origin_State'] == 'Kansas') & (data['Destination_State'] == 'Kansas')]

check[['Origin_Airport', 'Destination_Airport']].value_counts()

# 둘다 Kansas
# Out:
# Origin_Airport  Destination_Airport
# SLN             HYS                    69
# HYS             SLN                    54
# dtype: int64

# %%
for state in data['Origin_State'].unique():
    check = data[(data['Origin_State'] == state) & (data['Destination_State'] == state)]
    if (len(check) != 0) & (state != np.nan):
        print(state)
        print(check[['Origin_Airport', 'Destination_Airport']].value_counts())
        print('-'*50)
# Out:
# Illinois
# Origin_Airport  Destination_Airport
# MLI             ORD                    251
# ORD             MLI                    250
#                 PIA                    249
# PIA             ORD                    237
# CMI             ORD                    168
# ORD             CMI                    163
#                 SPI                    133
# SPI             ORD                    117
# UIN             ORD                     78
# ORD             UIN                     75
#                 BMI                     69
# BMI             ORD                     68
# dtype: int64
# --------------------------------------------------
# North Carolina
# Origin_Airport  Destination_Airport
# CLT             GSO                    261
#                 RDU                    255
# GSO             CLT                    254
# RDU             CLT                    244
# CLT             ILM                    242
# ILM             CLT                    240
# ...

# %%
# Out:
#                   ID  Month  Day_of_Month  Estimated_Departure_Time  \
# 91      TRAIN_000091     10             6                    1145.0
# 1545    TRAIN_001545      4             7                    1110.0
# 2066    TRAIN_002066      3            14                    1340.0
# 2613    TRAIN_002613      1             8                    1145.0
# 3564    TRAIN_003564     11             8                    1629.0
# ...              ...    ...           ...                       ...
# 997403  TRAIN_997403      1            28                    1530.0
# 998592  TRAIN_998592     12             6                     945.0
# 998686  TRAIN_998686      5             7                     715.0
# 999068  TRAIN_999068     11             3                     700.0
# 999628  TRAIN_999628      1            24                     913.0
#
#         Estimated_Arrival_Time  Cancelled  Diverted Origin_Airport  \
# 91                      1220.0          0         0            OGG
# ...
